# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %% [markdown]
# <h3>Importing the Libraries</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3>Loading the Dataset</h3>

# %%
tmr_data_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Data/FINAL_RESULT-9thSeptNew.csv')

# %%
tmr_data_df.head(2)
# Out:
#          Admit ID RFP % Present RFP Last Status RFP Last Internal Rating  \
# 0  CIC012021-8041           76%    Need No Help       Meets expectations
# 1  CIC012021-8044           89%  Need Less Help       Improvement needed
#
#    RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# 0                   0.0                           1.68
# 1                   3.6                           1.22
#
#    RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# 0                            1.72                              0.86
# 1                            1.51                              0.67
#
#    RFP Avg TRACK Score       Last Graduation    Year TechCategory  \
# 0                 4.26  B.E. / B.TECH Non IT  2019.0    FullStack
# 1                 3.40      B.E. / B.TECH CS  2020.0    AdvTech-1
#
#   Trial % Present  Trial Avg TRACK Score  \
# 0         100.00%                   3.69
# 1         100.00%                   3.23
#
# ...

# %% [markdown]
# <h3>Getting an overview of the Data</h3>

# %%
tmr_data_df.shape
# Out:
# (1144, 18)

# %%
tmr_data_df.describe()
# Out:
#        RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# count           1128.000000                    1117.000000
# mean               3.192083                       1.388993
# std                1.421935                       0.187434
# min                0.000000                       0.610000
# 25%                3.290000                       1.280000
# 50%                3.730000                       1.400000
# 75%                3.982500                       1.510000
# max                4.880000                       2.930000
#
#        RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# count                     1117.000000                       1117.000000
# mean                         1.516583                          0.802655
# std                          0.155638                          0.090226
# min                          0.700000                          0.350000
# ...

# %%
df = tmr_data_df.loc[(tmr_data_df['Year']>2022) | (tmr_data_df['Trial Learnability Score (Out of 2.0)'] > 2.0) | (tmr_data_df['Trial Communicability Score (Out of 1.0)']>1.0)]
df
# Out:
#             Admit ID RFP % Present RFP Last Status RFP Last Internal Rating  \
# 104  CIC012022-10935          100%    Need No Help     Exceeds expectations
# 124  CIC012022-10989           62%    Need No Help       Meets expectations
# 582  CIC052022-12151          100%  Need More Help       Improvement needed
# 862   CIC092021-9609           93%  Need Less Help       Meets expectations
# 884   CIC092021-9697           98%  Need Less Help       Meets expectations
#
#      RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# 104                  4.64                           1.73
# 124                  4.30                           1.74
# 582                  3.48                           1.17
# 862                  4.46                           1.39
# 884                  4.03                           1.48
#
#      RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# 104                            1.79                              0.97
# ...

# %%
# Correcting the rows with wrong 'Year' values

# tmr_data_df.loc[tmr_data_df["Year"] > 2022, 'Year'] = 2022

# %%
tmr_data_df = tmr_data_df.drop(tmr_data_df[(tmr_data_df['Admit ID'] == 'CIC012022-10935') | 
                                           (tmr_data_df['Admit ID'] == 'CIC012022-10989') | 
                                           (tmr_data_df['Admit ID'] == 'CIC052022-12151') | 
                                           (tmr_data_df['Admit ID'] == 'CIC092021-9609') | 
                                           (tmr_data_df['Admit ID'] == 'CIC092021-9697')].index)

# %%
tmr_data_df.describe()
# Out:
#        RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# count           1123.000000                    1112.000000
# mean               3.187676                       1.388485
# std                1.423304                       0.187144
# min                0.000000                       0.610000
# 25%                3.290000                       1.280000
# 50%                3.730000                       1.400000
# 75%                3.980000                       1.510000
# max                4.880000                       2.930000
#
#        RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# count                     1112.000000                       1112.000000
# mean                         1.515929                          0.802433
# std                          0.155543                          0.090275
# min                          0.700000                          0.350000
# ...

# %%
tmr_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1139 entries, 0 to 1143
# Data columns (total 18 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Admit ID                                  1139 non-null   object
#  1   RFP % Present                             1139 non-null   object
#  2   RFP Last Status                           1111 non-null   object
#  3   RFP Last Internal Rating                  1111 non-null   object
#  4   RFP Last TRACK Score                      1123 non-null   float64
#  5   RFP Tech Ability
# (Out of 2)              1112 non-null   float64
#  6   RFP- Learnability
# (Out of 2)             1112 non-null   float64
#  7   RFP-Communicability
# (Out of 1)           1112 non-null   float64
#  8   RFP Avg TRACK Score                       1112 non-null   float64
#  9   Last Graduation                           1116 non-null   object
# ...

# %%
# Dropping the 'Admit ID' column

tmr_data_df.drop('Admit ID', axis=1, inplace=True)

# %%
# Removing the % symbol from the 'Trial % Present' and 'RFP % Present' columns

tmr_data_df.replace('\%', '', regex=True,inplace=True)

# Changing the type of 'Trial % Present' and 'RFP % Present' columns from object to float
tmr_data_df['Trial % Present'] = tmr_data_df['Trial % Present'].astype('float64')
tmr_data_df['RFP % Present'] = tmr_data_df['RFP % Present'].astype('float64')
tmr_data_df.head(2)
# Out:
#    RFP % Present RFP Last Status RFP Last Internal Rating  \
# 0           76.0    Need No Help       Meets expectations
# 1           89.0  Need Less Help       Improvement needed
#
#    RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# 0                   0.0                           1.68
# 1                   3.6                           1.22
#
#    RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# 0                            1.72                              0.86
# 1                            1.51                              0.67
#
#    RFP Avg TRACK Score       Last Graduation    Year TechCategory  \
# 0                 4.26  B.E. / B.TECH Non IT  2019.0    FullStack
# 1                 3.40      B.E. / B.TECH CS  2020.0    AdvTech-1
#
#    Trial % Present  Trial Avg TRACK Score  \
# 0            100.0                   3.69
# 1            100.0                   3.23
#
#    Trial Communicability Score (Out of 1.0) Trial Last Internal Rating  \
# ...

# %%
tmr_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1139 entries, 0 to 1143
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   RFP % Present                             1139 non-null   float64
#  1   RFP Last Status                           1111 non-null   object
#  2   RFP Last Internal Rating                  1111 non-null   object
#  3   RFP Last TRACK Score                      1123 non-null   float64
#  4   RFP Tech Ability
# (Out of 2)              1112 non-null   float64
#  5   RFP- Learnability
# (Out of 2)             1112 non-null   float64
#  6   RFP-Communicability
# (Out of 1)           1112 non-null   float64
#  7   RFP Avg TRACK Score                       1112 non-null   float64
#  8   Last Graduation                           1116 non-null   object
#  9   Year                                      1100 non-null   float64
# ...

# %%
tmr_data_df.columns.tolist()
# Out:
# ['RFP % Present',
#  'RFP Last Status',
#  'RFP Last Internal Rating',
#  'RFP Last TRACK Score',
#  'RFP Tech Ability \n(Out of 2)',
#  'RFP- Learnability \n(Out of 2)',
#  'RFP-Communicability \n(Out of 1)',
#  'RFP Avg TRACK Score',
#  'Last Graduation',
#  'Year',
#  'TechCategory',
#  'Trial % Present',
#  'Trial Avg TRACK Score',
#  'Trial Communicability Score (Out of 1.0)',
#  'Trial Last Internal Rating',
#  'Trial Learnability Score (Out of 2.0)',
#  'Trial Techability Score (Out of 2.0)']

# %%
# Segregating the categorical and numerical variables
categorical_cols = []
numerical_cols = []
for col in tmr_data_df.columns:
    if tmr_data_df[col].dtype == "object":
        categorical_cols.append(col)
    else:
        numerical_cols.append(col)

# %%
# Numerical Columns

numerical_cols
# Out:
# ['RFP % Present',
#  'RFP Last TRACK Score',
#  'RFP Tech Ability \n(Out of 2)',
#  'RFP- Learnability \n(Out of 2)',
#  'RFP-Communicability \n(Out of 1)',
#  'RFP Avg TRACK Score',
#  'Year',
#  'Trial % Present',
#  'Trial Avg TRACK Score',
#  'Trial Communicability Score (Out of 1.0)',
#  'Trial Learnability Score (Out of 2.0)',
#  'Trial Techability Score (Out of 2.0)']

# %%
# Categorical Columns

categorical_cols
# Out:
# ['RFP Last Status',
#  'RFP Last Internal Rating',
#  'Last Graduation',
#  'TechCategory',
#  'Trial Last Internal Rating']

# %% [markdown]
# <h3>Checking for null / missing values</h3>

# %%
pd.DataFrame(tmr_data_df.isna().sum())
# Out:
#                                             0
# RFP % Present                               0
# RFP Last Status                            28
# RFP Last Internal Rating                   28
# RFP Last TRACK Score                       16
# RFP Tech Ability \n(Out of 2)              27
# RFP- Learnability \n(Out of 2)             27
# RFP-Communicability \n(Out of 1)           27
# RFP Avg TRACK Score                        27
# Last Graduation                            23
# Year                                       39
# TechCategory                               29
# Trial % Present                             3
# Trial Avg TRACK Score                      63
# Trial Communicability Score (Out of 1.0)   66
# Trial Last Internal Rating                171
# Trial Learnability Score (Out of 2.0)      66
# Trial Techability Score (Out of 2.0)       66

# %%
tmr_data_df = tmr_data_df.dropna(subset=['TechCategory','Trial Last Internal Rating',
                                         'Trial Techability Score (Out of 2.0)',
                                         'Year','RFP Avg TRACK Score','RFP Last Internal Rating','RFP Last TRACK Score'])

# %%
pd.DataFrame(tmr_data_df.isna().sum())
# Out:
#                                           0
# RFP % Present                             0
# RFP Last Status                           0
# RFP Last Internal Rating                  0
# RFP Last TRACK Score                      0
# RFP Tech Ability \n(Out of 2)             0
# RFP- Learnability \n(Out of 2)            0
# RFP-Communicability \n(Out of 1)          0
# RFP Avg TRACK Score                       0
# Last Graduation                           0
# Year                                      0
# TechCategory                              0
# Trial % Present                           0
# Trial Avg TRACK Score                     0
# Trial Communicability Score (Out of 1.0)  0
# Trial Last Internal Rating                0
# Trial Learnability Score (Out of 2.0)     0
# Trial Techability Score (Out of 2.0)      0

# %%
tmr_data_df.shape
# Out:
# (871, 17)

# %%
# pd.DataFrame(tmr_data_df.isnull().sum()/len(tmr_data_df)*100)

# %% [markdown]
# <h3>Unvariate Analysis of Numerical Columns</h3>

# %%
# fig, axs = plt.subplots(4, 3, figsize=(20, 35))
 
# fig.suptitle('PDF for all Numerical Columns')
# plt.style.use('fivethirtyeight')
# # plt.xkcd()

# sns.histplot(data=tmr_data_df, x="Trial % Present", kde=True, color="skyblue", ax=axs[0, 0]).set(title='PDF of Trial % Present')
# sns.histplot(data=tmr_data_df, x="Trail Avg TRACK Score", kde=True, color="skyblue", ax=axs[0, 1]).set(title='PDF of Trail Avg TRACK Score')
# sns.histplot(data=tmr_data_df, x="Trail Techability Score (Out of 2.0)", kde=True, color="olive", ax=axs[0, 2]).set(title='PDF of Trail Techability Score')
# sns.histplot(data=tmr_data_df, x="Trail Learnability Score (Out of 2.0)", kde=True, color="teal", ax=axs[1, 0]).set(title='PDF of Trail Learnability Score')
# sns.histplot(data=tmr_data_df, x="Trail Communicability Score (Out of 1.0)", kde=True, color="green", ax=axs[1, 1]).set(title='PDF of Trail Communicability Score')
# sns.histplot(data=tmr_data_df, x="RFP % Present", kde=True, color="green", ax=axs[1, 2]).set(title='PDF of Trail Communicability Score')
# sns.histplot(data=tmr_data_df, x="RFP Avg TRACK Score", kde=True, color="purple", ax=axs[2, 0]).set(title='PDF of RFP Avg TRACK Score')
# sns.histplot(data=tmr_data_df, x="RFP Last TRACK Score", kde=True, color="red", ax=axs[2, 1]).set(title='PDF of RFP Last TRACK Score')
# sns.histplot(data=tmr_data_df, x="RFP Tech Ability \n(Out of 2)", kde=True, color="cyan", ax=axs[2, 2]).set(title='PDF of RFP Tech Ability')
# sns.histplot(data=tmr_data_df, x="RFP- Learnability \n(Out of 2)", kde=True, color="violet", ax=axs[3, 0]).set(title='PDF of RFP- Learnability')
# sns.histplot(data=tmr_data_df, x="RFP-Communicability \n(Out of 1)", kde=True, color="darkblue", ax=axs[3, 1]).set(title='PDF of RFP-Communicability')
# sns.histplot(data=tmr_data_df, x="Year", kde=True, color="coral", ax=axs[3, 2]).set(title='PDF of Year')
# plt.show()

# %% [markdown]
# <h3>Univariate Analysis of Categorical Columns</h3>

# %% [markdown]
# <b>Bucketting the 'Last Graduation' column values</b>

# %%
pd.DataFrame(tmr_data_df['Last Graduation'].value_counts())
# len(list(tmr_data_df['Last Graduation'].value_counts()))
# Out:
#                                        Last Graduation
# B.E. / B.TECH Non IT                               388
# B.E. / B.TECH CS                                   211
# B.E. / B.TECH IT                                    66
# MCA                                                 61
# B.E. / B.TECH                                       22
# MSc CS/IT                                           20
# BSc CS                                              16
# M.E. / M.Tech CS/IT                                 14
# M.E. / M.Tech Non IT                                 9
# BSc IT                                               6
# PG Non IT                                            6
# BSc Non IT                                           6
# B.E. Mechanical Engineering                          5
# MSc Non IT                                           5
# PG CS/IT                                             4
# BCA IT                                               4
# ...

# %%
def bucketing_graduation(row):
    if row['Last Graduation'] in ['B.E. / B.TECH CS', 'B.E. / B.TECH IT', 'B.Tech Information Technology', 'Computer Science', 'B.E. Computer Engineering', 'B.Tech Computer Science','B.E. Information Technology']:
        return 'BE_BTECH_CS_IT'
    if row['Last Graduation'] in ['B.E. / B.TECH Non IT','B.E. Mechanical Engineering','Mechatronics Engineering','B.Tech Chemical engineering','B.Tech Electrical Engineering','B.Tech Electronics Engineering','B.E. Electrical Engineering','B.E. Electronics & Communication Engineering','B.E. CIVIL ENGINEERING','B.E. Electronics & Telecommunications']:
        return 'BE_BTECH_NON_IT'
    if row['Last Graduation'] in ['B.E. / B.TECH', 'B-tech']:
        return 'BE_BTECH'
    if row['Last Graduation'] in ['MCA', 'MSc CS/IT', 'MCA IT']:
        return 'MCA_MSc_CS_IT'
    if row['Last Graduation'] in ['MSc Non IT']:
        return 'MSc_Non_IT'
    if row['Last Graduation'] in ['M.E. / M.Tech CS/IT','PG CS/IT']:
        return 'ME_MTECH_PG_CS_IT'
    if row['Last Graduation'] in ['M.E. / M.Tech Non IT','PG Non IT']:
        return 'ME_MTECH_PG_Non_IT'
    if row['Last Graduation'] in ['BSc CS','BSc IT','BCA IT','BCA','BCA CS','Computer Application','Other IT']:
        return 'BCA_BSc_CS_Other_IT'
    if row['Last Graduation'] in ['BSc Non IT','BSc','Other Non IT','Diploma Non IT']:
        return 'BCA_BSc_Other_Diploma_Non_IT'


tmr_data_df['Last Graduation'] = tmr_data_df.apply(lambda row: bucketing_graduation(row), axis=1)

# %%
# After Bucketing

tmr_data_df['Last Graduation'].value_counts()
# Out:
# BE_BTECH_NON_IT                 399
# BE_BTECH_CS_IT                  284
# MCA_MSc_CS_IT                    84
# BCA_BSc_CS_Other_IT              33
# BE_BTECH                         23
# ME_MTECH_PG_CS_IT                18
# ME_MTECH_PG_Non_IT               15
# BCA_BSc_Other_Diploma_Non_IT     10
# MSc_Non_IT                        5
# Name: Last Graduation, dtype: int64

# %%
# color=['red','green','yellow','grey','cyan','violet','olive','coral','blue']
# for category in categorical_cols[:-1]:
#     cat_len = len(tmr_data_df[category].value_counts())
#     tmr_data_df[category].value_counts().sort_values().plot(kind = 'bar', color=color[:cat_len])
#     plt.xticks(rotation=90, horizontalalignment="center")
#     plt.title(category)
#     plt.xlabel(f"{category} Categories")
#     plt.ylabel("Counts")
#     plt.show()

# %%
# sns.countplot(x ='TechCategory', data = tmr_data_df)
# plt.xticks(rotation=90, horizontalalignment="center")
# plt.show()

# %% [markdown]
# <h3>Handling missing data using mean imputation and mode replacement</h3>

# %%
# Note:  As we can see the from the above figure that all the numerical columns are having 
# a gausian distribution/not skewed hence we can use 'Mean' to replace the missing values.

# handling the missing rows in 'RFP Last TRACK Score' column using mean imputation
# tmr_data_df["RFP Last TRACK Score"].fillna(tmr_data_df["RFP Last TRACK Score"].mean(), inplace = True)

# handling the missing rows in 'Year' column using mode replacement
# tmr_data_df['Year'].fillna(tmr_data_df['Year'].mode()[0], inplace=True)

# %% [markdown]
# <h3>Encoding the Categorical Variables</h3>

# %%
categorical_cols
# Out:
# ['RFP Last Status',
#  'RFP Last Internal Rating',
#  'Last Graduation',
#  'TechCategory',
#  'Trial Last Internal Rating']

# %%
# For column 'Trail Last Internal Rating'

# Before Encoding
tmr_data_df['Trial Last Internal Rating'].value_counts()
# Out:
# Meets expectations      375
# Improvement needed      363
# Exceeds expectations     99
# Unsatisfactory           29
# Exceptional               5
# Name: Trial Last Internal Rating, dtype: int64

# %%
tmr_data_df['Trial Last Internal Rating'] = tmr_data_df['Trial Last Internal Rating'].replace({'Unsatisfactory': 0, 'Improvement needed': 1,
                                                                                              'Meets expectations':2, 'Exceeds expectations':3,
                                                                                              'Exceptional':4})

# %%
# After Encoding
tmr_data_df['Trial Last Internal Rating'].value_counts()
# Out:
# 2    375
# 1    363
# 3     99
# 0     29
# 4      5
# Name: Trial Last Internal Rating, dtype: int64

# %%
# For column 'RFP Last Internal Rating'

# Before Encoding
tmr_data_df['RFP Last Internal Rating'].value_counts()
# Out:
# Improvement needed      474
# Meets expectations      344
# Exceeds expectations     27
# Unsatisfactory           24
# Exceptional               2
# Name: RFP Last Internal Rating, dtype: int64

# %%
tmr_data_df['RFP Last Internal Rating'] = tmr_data_df['RFP Last Internal Rating'].replace({'Unsatisfactory': 0, 'Improvement needed': 1,
                                                                                              'Meets expectations':2, 'Exceeds expectations':3,
                                                                                              'Exceptional':4})

# %%
# After Encoding
tmr_data_df['RFP Last Internal Rating'].value_counts()
# Out:
# 1    474
# 2    344
# 3     27
# 0     24
# 4      2
# Name: RFP Last Internal Rating, dtype: int64

# %%
# For column 'RFP Last Status'

# Before Encoding
tmr_data_df['RFP Last Status'].value_counts()
# Out:
# Need Less Help    539
# Need More Help    234
# Need No Help       98
# Name: RFP Last Status, dtype: int64

# %%
# rfp_status_df = pd.DataFrame(tmr_data_df['RFP Last Status'].value_counts()).reset_index()
# rfp_status_df.rename(columns = {'index':'rfp_last_status', 'RFP Last Status':'value_count'}, inplace = True)
# rfp_status_df.head(3)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
# After Encoding

tmr_data_df['RFP Last Status'] = label_encoder.fit_transform(tmr_data_df['RFP Last Status'])
tmr_data_df['RFP Last Status'].value_counts()
# Out:
# 0    539
# 1    234
# 2     98
# Name: RFP Last Status, dtype: int64

# %%
# For column 'Last Graduation'

# Before Encoding
tmr_data_df['Last Graduation'].value_counts()
# Out:
# BE_BTECH_NON_IT                 399
# BE_BTECH_CS_IT                  284
# MCA_MSc_CS_IT                    84
# BCA_BSc_CS_Other_IT              33
# BE_BTECH                         23
# ME_MTECH_PG_CS_IT                18
# ME_MTECH_PG_Non_IT               15
# BCA_BSc_Other_Diploma_Non_IT     10
# MSc_Non_IT                        5
# Name: Last Graduation, dtype: int64

# %%
# pip install category_encoders

# %%
# Binary Encoding the 'Last Graduation' column

# import category_encoders as ce
# binary_encoder = ce.BinaryEncoder(cols=['Last Graduation'], return_df=True)
# data_encoded = binary_encoder.fit_transform(tmr_data_df['Last Graduation'])
# data_encoded

# %%
# tmr_data_df.insert(6, 'Last Graduation_0', data_encoded['Last Graduation_0'].values)
# tmr_data_df.insert(7, 'Last Graduation_1', data_encoded['Last Graduation_1'].values)
# tmr_data_df.insert(8, 'Last Graduation_2', data_encoded['Last Graduation_2'].values)
# tmr_data_df.insert(9, 'Last Graduation_3', data_encoded['Last Graduation_3'].values)
# tmr_data_df.head(4)

# %%
tmr_data_df['Last Graduation'] = tmr_data_df['Last Graduation'].replace({'BE_BTECH_NON_IT': 0, 'BE_BTECH_CS_IT': 1,
                                                                        'MCA_MSc_CS_IT':2, 'BCA_BSc_CS_Other_IT':3,
                                                                        'ME_MTECH_PG_CS_IT':4, 'BE_BTECH':5,
                                                                        'ME_MTECH_PG_Non_IT':6, 'BCA_BSc_Other_Diploma_Non_IT':7,
                                                                        'MSc_Non_IT':8})

# %%
# After Encoding
tmr_data_df['Last Graduation'].value_counts()
# Out:
# 0    399
# 1    284
# 2     84
# 3     33
# 5     23
# 4     18
# 6     15
# 7     10
# 8      5
# Name: Last Graduation, dtype: int64

# %%
# For column 'TechCategory'

# Before Encoding
tmr_data_df['TechCategory'].value_counts()
# Out:
# FullStack    419
# AdvTech-1    195
# AdvTech-2     92
# BasicTech     78
# StdTech       64
# DeepTech      23
# Name: TechCategory, dtype: int64

# %%
tmr_data_df['TechCategory'] = tmr_data_df['TechCategory'].replace({'FullStack': 3, 'AdvTech-1': 2,
                                                                    'AdvTech-2':2, 'BasicTech':1,
                                                                    'StdTech':0, 'DeepTech':3,
                                                                  })

# %%
# After Encoding
tmr_data_df['TechCategory'].value_counts()
# Out:
# 3    442
# 2    287
# 1     78
# 0     64
# Name: TechCategory, dtype: int64

# %%
# tmr_data_df.append(data_encoded)

# %%
# tmr_data_df = pd.concat([tmr_data_df, data_encoded],axis = 1)

# %%
# tmr_data_df.drop('Last Graduation', axis=1, inplace=True)
# tmr_data_df.head(4)

# %% [markdown]
# <h3>Bivariate Analysis</h3>

# %%
# data = list(tmr_data_df['Trial % Present'].values)
# label = list(tmr_data_df['TechCategory'].values)

# %%
# sns.barplot(x ='TechCategory', y ='Trial % Present', data = tmr_data_df,
#             palette ='plasma')
# plt.xticks(rotation=90, horizontalalignment="center")
# plt.show()

# %%
# sns.swarmplot(x ='TechCategory', y ='Trail Avg TRACK Score', data = tmr_data_df)
# plt.xticks(rotation=90, horizontalalignment="center")
# plt.show()

# %%
# sns.violinplot(x ='TechCategory', y ='Trail Techability Score (Out of 2.0)', data = tmr_data_df)
# plt.xticks(rotation=90, horizontalalignment="center")
# # sns.swarmplot(x ='TechCategory', y ='Trail Techability Score (Out of 2.0)', data = tmr_data_df, color ='black')
# plt.show()

# %%
# sns.factorplot(x ='TechCategory', y ='Trail Learnability Score (Out of 2.0)', data = tmr_data_df, kind ='bar')
# plt.xticks(rotation=90, horizontalalignment="center")
# plt.show()

# %%
tmr_data_df.head(3)
# Out:
#    RFP % Present  RFP Last Status  RFP Last Internal Rating  \
# 0           76.0                2                         2
# 1           89.0                0                         1
# 2           79.0                0                         2
#
#    RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# 0                   0.0                           1.68
# 1                   3.6                           1.22
# 2                   4.4                           1.74
#
#    RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# 0                            1.72                              0.86
# 1                            1.51                              0.67
# 2                            1.75                              0.93
#
#    RFP Avg TRACK Score  Last Graduation    Year  TechCategory  \
# 0                 4.26                0  2019.0             3
# 1                 3.40                1  2020.0             2
# ...

# %%
# fig, axs = plt.subplots(4, 3, figsize=(35, 35))
 
# fig.suptitle('Relation between class label(TechCategory) and numerical variables')
# plt.style.use('fivethirtyeight')
# # plt.xkcd()

# sns.barplot(x ='TechCategory', y ='Trial % Present', ax=axs[0, 0], data = tmr_data_df,palette ='plasma').set(title='TechCategory vs Trial % Present')
# sns.barplot(x ='TechCategory', y ='Trail Avg TRACK Score', ax=axs[0, 1], data = tmr_data_df,palette ='vlag').set(title='TechCategory vs Trail Avg TRACK Score')
# sns.barplot(x ='TechCategory', y ='Trail Techability Score (Out of 2.0)', ax=axs[0, 2], data = tmr_data_df,palette ='mako').set(title='TechCategory vs Trail Techability Score')
# sns.barplot(x ='TechCategory', y ='Trail Learnability Score (Out of 2.0)', ax=axs[1, 0], data = tmr_data_df,palette ='viridis').set(title='TechCategory vs Trail Learnability Score')
# sns.barplot(x ='TechCategory', y ='Trail Communicability Score (Out of 1.0)', ax=axs[1, 1], data = tmr_data_df,palette ='rocket_r').set(title='TechCategory vs Trail Communicability Score')
# sns.barplot(x ='TechCategory', y ='RFP % Present', ax=axs[1, 2], data = tmr_data_df,palette ='crest').set(title='TechCategory vs RFP % Present')
# sns.barplot(x ='TechCategory', y ='RFP Avg TRACK Score', ax=axs[2, 0], data = tmr_data_df,palette ='flare').set(title='TechCategory vs RFP Avg TRACK Score')
# sns.barplot(x ='TechCategory', y ='RFP Last TRACK Score', ax=axs[2, 1], data = tmr_data_df,palette ='cubehelix').set(title='TechCategory vs RFP Last TRACK Score')
# sns.barplot(x ='TechCategory', y ='RFP Tech Ability \n(Out of 2)', ax=axs[2, 2], data = tmr_data_df,palette ='rocket').set(title='TechCategory vs RFP Tech Ability')
# sns.barplot(x ='TechCategory', y ='RFP- Learnability \n(Out of 2)', ax=axs[3, 0], data = tmr_data_df,palette ='icefire').set(title='TechCategory vs RFP- Learnability')
# sns.barplot(x ='TechCategory', y ='RFP-Communicability \n(Out of 1)', ax=axs[3, 1], data = tmr_data_df,palette ='Blues').set(title='TechCategory vs RFP-Communicability')
# sns.barplot(x ='TechCategory', y ='Year', ax=axs[3, 2], data = tmr_data_df,palette ='cool').set(title='TechCategory and Year')
# plt.show()

# %%
# Multivariate

# %%
# plt.figure(figsize=(15,10))
# sns.swarmplot(x ='RFP Last Status', y ='RFP Avg TRACK Score', data = tmr_data_df, hue ='TechCategory')
# plt.xticks([0.25, 1.25, 2.25], rfp_status_df["rfp_last_status"],horizontalalignment="right")
# plt.show()

# %% [markdown]
# <h3>Correlation between variables</h3>

# %%
tmr_data_df.head(2)
# Out:
#    RFP % Present  RFP Last Status  RFP Last Internal Rating  \
# 0           76.0                2                         2
# 1           89.0                0                         1
#
#    RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# 0                   0.0                           1.68
# 1                   3.6                           1.22
#
#    RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# 0                            1.72                              0.86
# 1                            1.51                              0.67
#
#    RFP Avg TRACK Score  Last Graduation    Year  TechCategory  \
# 0                 4.26                0  2019.0             3
# 1                 3.40                1  2020.0             2
#
#    Trial % Present  Trial Avg TRACK Score  \
# 0            100.0                   3.69
# 1            100.0                   3.23
#
#    Trial Communicability Score (Out of 1.0)  Trial Last Internal Rating  \
# ...

# %%
print(tmr_data_df.shape)
tmr_data_df.to_csv('/home/hp/Desktop/TMR-EDA/Data/encoded_tmr_data.csv',index=False)
# Out:
# (871, 17)

# %%
correlation = tmr_data_df.corr()
print("correlation of Feature with Target ---->\n")
print(correlation["TechCategory"].sort_values(ascending = False))
# Out:
# correlation of Feature with Target ---->
#
# TechCategory                                1.000000
# RFP Avg TRACK Score                         0.451116
# RFP- Learnability \n(Out of 2)              0.399730
# RFP Tech Ability \n(Out of 2)               0.392966
# RFP-Communicability \n(Out of 1)            0.360899
# RFP Last Internal Rating                    0.302086
# Trial Learnability Score (Out of 2.0)       0.221309
# Trial Avg TRACK Score                       0.201028
# Trial Last Internal Rating                  0.189556
# Trial Techability Score (Out of 2.0)        0.181127
# Trial Communicability Score (Out of 1.0)    0.180163
# RFP % Present                               0.079583
# Year                                        0.077029
# Trial % Present                             0.049864
# RFP Last TRACK Score                        0.035167
# Last Graduation                             0.008828
# RFP Last Status                            -0.052527
# ...

# %%
# feature_data = tmr_data_df.drop(columns="TechCategory", axis=1)
# target_data = tmr_data_df["TechCategory"]
plt.figure(figsize=(16, 10))
dataplot = sns.heatmap(tmr_data_df.corr(),  annot = True, fmt='.1g', vmin=-1, vmax=1, center= 0, linewidths=3, linecolor='black')

plt.show()

# %%
tmr_data_df.drop(columns=['RFP Last Status','Last Graduation','RFP Last TRACK Score','Trial % Present','Year','RFP % Present','RFP Avg TRACK Score','Trial Avg TRACK Score'],axis=1,inplace=True)

# %%
tmr_data_df.head(2)
# Out:
#    RFP Last Internal Rating  RFP Tech Ability \n(Out of 2)  \
# 0                         2                           1.68
# 1                         1                           1.22
#
#    RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# 0                            1.72                              0.86
# 1                            1.51                              0.67
#
#    TechCategory  Trial Communicability Score (Out of 1.0)  \
# 0             3                                      0.59
# 1             2                                      0.62
#
#    Trial Last Internal Rating  Trial Learnability Score (Out of 2.0)  \
# 0                           3                                  1.475
# 1                           2                                  1.050
#
#    Trial Techability Score (Out of 2.0)
# 0                                 1.625
# 1                                 1.560

# %%
plt.figure(figsize=(16, 10))
dataplot = sns.heatmap(tmr_data_df.corr(),  annot = True, fmt='.1g', vmin=-1, vmax=1, center= 0, linewidths=3, linecolor='black')

plt.show()

# %%
tmr_data_df.columns
# Out:
# Index(['RFP Last Internal Rating', 'RFP Tech Ability \n(Out of 2)',
#        'RFP- Learnability \n(Out of 2)', 'RFP-Communicability \n(Out of 1)',
#        'TechCategory', 'Trial Communicability Score (Out of 1.0)',
#        'Trial Last Internal Rating', 'Trial Learnability Score (Out of 2.0)',
#        'Trial Techability Score (Out of 2.0)'],
#       dtype='object')

# %% [markdown]
# <h3>Feature Selection for Training<h3>

# %%
data_column_list = [
                    'RFP Last Internal Rating',
                    'RFP Tech Ability \n(Out of 2)',
                    'RFP- Learnability \n(Out of 2)',
                    'RFP-Communicability \n(Out of 1)',
                    'Trial Last Internal Rating',
                    'Trial Techability Score (Out of 2.0)',
                    'Trial Learnability Score (Out of 2.0)',
                    'Trial Communicability Score (Out of 1.0)',
                    'TechCategory'
                    ]


training_data = tmr_data_df.filter(data_column_list, axis=1)

# %%
training_data = training_data.rename(columns={ 
                                               'RFP Tech Ability \n(Out of 2)':'RFP Tech Ability',
                                               'RFP- Learnability \n(Out of 2)':'RFP- Learnability',
                                               'RFP-Communicability \n(Out of 1)':'RFP-Communicability',
                                               'Trial Techability Score (Out of 2.0)':'Trial Techability Score',
                                               'Trial Learnability Score (Out of 2.0)':'Trial Learnability Score',
                                               'Trial Communicability Score (Out of 1.0)':'Trial Communicability Score'
                                             })

# %%
training_data.head()
# Out:
#    RFP Last Internal Rating  RFP Tech Ability  RFP- Learnability  \
# 0                         2              1.68               1.72
# 1                         1              1.22               1.51
# 2                         2              1.74               1.75
# 4                         1              1.21               1.29
# 5                         2              1.59               1.66
#
#    RFP-Communicability  Trial Last Internal Rating  Trial Techability Score  \
# 0                 0.86                           3                    1.625
# 1                 0.67                           2                    1.560
# 2                 0.93                           2                    1.730
# 4                 0.74                           1                    1.400
# 5                 0.88                           1                    1.400
#
#    Trial Learnability Score  Trial Communicability Score  TechCategory
# ...

# %%
sns.pairplot(data=training_data, hue = 'TechCategory', palette='viridis')
plt.show()

# %%
training_data.columns
# Out:
# Index(['RFP Last Internal Rating', 'RFP Tech Ability', 'RFP- Learnability',
#        'RFP-Communicability', 'Trial Last Internal Rating',
#        'Trial Techability Score', 'Trial Learnability Score',
#        'Trial Communicability Score', 'TechCategory'],
#       dtype='object')

# %%
category = [0,1,2,3]
labels = ['StdTech','BasicTech','AdvTech(1+2)','FullStack+DeepTech']

# %%
sns.countplot(training_data["TechCategory"]).set_title('Count for different TechCategories')
plt.xticks(category,labels,rotation ='vertical')
plt.show()
# Out:
# /home/hp/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,12))
sns.swarmplot(x ='TechCategory', y ='RFP Tech Ability', data = training_data,size=5)
plt.xticks(category,labels,rotation ='vertical')
plt.show()

# %%
sns.violinplot(x ='TechCategory', y ='RFP Tech Ability', data = training_data)
plt.xticks(category,labels,rotation ='vertical')
plt.show()

# %%
sns.stripplot(x="TechCategory", y="RFP Tech Ability", data=training_data)
plt.show()

# %%
sns.violinplot(x ='TechCategory', y ='RFP- Learnability', data = training_data)
plt.xticks(category,labels,rotation ='vertical')
plt.show()

# %%
sns.violinplot(x ='TechCategory', y ='RFP-Communicability', data = training_data)
plt.xticks(category,labels,rotation ='vertical')
plt.show()

# %%
sns.violinplot(x ='TechCategory', y ='Trial Techability Score', data = training_data)
plt.xticks(category,labels,rotation ='vertical')
plt.show()

# %%
sns.violinplot(x ='TechCategory', y ='Trial Learnability Score', data = training_data)
plt.xticks(category,labels,rotation ='vertical')
plt.show()

# %%
sns.violinplot(x ='TechCategory', y ='Trial Communicability Score', data = training_data)
plt.xticks(category,labels,rotation ='vertical')
plt.show()

# %% [markdown]
# <h2>Feature Standardisation</h2>

# %%
target = training_data['TechCategory']
features = training_data.drop(columns='TechCategory', axis=1)

# %%
print(target.shape)
print(features.shape)
# Out:
# (871,)
# (871, 8)

# %%
columns = list(features.columns)

# %%
features.head()
# Out:
#    RFP Last Internal Rating  RFP Tech Ability  RFP- Learnability  \
# 0                         2              1.68               1.72
# 1                         1              1.22               1.51
# 2                         2              1.74               1.75
# 4                         1              1.21               1.29
# 5                         2              1.59               1.66
#
#    RFP-Communicability  Trial Last Internal Rating  Trial Techability Score  \
# 0                 0.86                           3                    1.625
# 1                 0.67                           2                    1.560
# 2                 0.93                           2                    1.730
# 4                 0.74                           1                    1.400
# 5                 0.88                           1                    1.400
#
#    Trial Learnability Score  Trial Communicability Score
# 0                     1.475                         0.59
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaling = StandardScaler()
features = scaling.fit_transform(training_data)

# %%
training_data
# Out:
#       RFP Last Internal Rating  RFP Tech Ability  RFP- Learnability  \
# 0                            2              1.68               1.72
# 1                            1              1.22               1.51
# 2                            2              1.74               1.75
# 4                            1              1.21               1.29
# 5                            2              1.59               1.66
# ...                        ...               ...                ...
# 1139                         1              1.41               1.42
# 1140                         1              1.26               1.38
# 1141                         1              1.39               1.46
# 1142                         1              1.37               1.40
# 1143                         2              1.51               1.70
#
#       RFP-Communicability  Trial Last Internal Rating  \
# 0                    0.86                           3
# ...

# %%
cols = list(training_data.columns)

# %%
features = pd.DataFrame(features,columns=cols)
features.head()
# Out:
#    RFP Last Internal Rating  RFP Tech Ability  RFP- Learnability  \
# 0                  0.918320          1.580360           1.273368
# 1                 -0.710716         -0.911718          -0.048042
# 2                  0.918320          1.905414           1.462140
# 3                 -0.710716         -0.965893          -1.432376
# 4                  0.918320          1.092780           0.895822
#
#    RFP-Communicability  Trial Last Internal Rating  Trial Techability Score  \
# 0             0.637806                    1.817820                 0.740809
# 1            -1.447761                    0.479425                 0.529366
# 2             1.406174                    0.479425                 1.082371
# 3            -0.679394                   -0.858970                 0.008892
# 4             0.857340                   -0.858970                 0.008892
#
#    Trial Learnability Score  Trial Communicability Score  TechCategory
# ...

# %%
correlation = features.corr()
print("correlation of Feature with Target ---->\n")
print(correlation["TechCategory"].sort_values(ascending = False))
# Out:
# correlation of Feature with Target ---->
#
# TechCategory                   1.000000
# RFP- Learnability              0.399730
# RFP Tech Ability               0.392966
# RFP-Communicability            0.360899
# RFP Last Internal Rating       0.302086
# Trial Learnability Score       0.221309
# Trial Last Internal Rating     0.189556
# Trial Techability Score        0.181127
# Trial Communicability Score    0.180163
# Name: TechCategory, dtype: float64

# %% [markdown]
# <h2>Splitting our data into Train & Test</h2>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target,test_size=0.15, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (740, 9)
# (740,)
# (131, 9)
# (131,)

# %%
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# 3    363
# 2    252
# 1     70
# 0     55
# Name: TechCategory, dtype: int64
# 3    79
# 2    35
# 0     9
# 1     8
# Name: TechCategory, dtype: int64

# %% [markdown]
# <h2>Logistic Regression</h2>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report
logistic_regression = LogisticRegression(random_state=0)
logistic_regression.fit(X_train, y_train)
# print(logistic_regression.score(X_test,y_test))
y_pred = logistic_regression.predict(X_test)

# %%
cf_matrix = confusion_matrix(y_test,y_pred)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        79
#
#     accuracy                           1.00       131
#    macro avg       1.00      1.00      1.00       131
# weighted avg       1.00      1.00      1.00       131

# %%
cf_matrix
# cf_matrix.ravel()
# tn, fp, fn, tp = cf_matrix.ravel()
# print("True Negatives: ",tn)
# print("False Positives: ",fp)
# print("False Negatives: ",fn)
# print("True Positives: ",tp)

# Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
# print("Accuracy {:0.2f}%:".format(Accuracy))
# Out:
# array([[ 9,  0,  0,  0],
#        [ 0,  8,  0,  0],
#        [ 0,  0, 35,  0],
#        [ 0,  0,  0, 79]])

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cf_matrix,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %% [markdown]
# <h2>Random Forest</h2>

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(n_estimators=20, random_state=0)
RF.fit(X_train, y_train)
y_pred = RF.predict(X_test)

cf_matrix = confusion_matrix(y_test,y_pred)
print(classification_report(y_test,y_pred))

# tn, fp, fn, tp = cf_matrix.ravel()
# print("True Negatives: ",tn)
# print("False Positives: ",fp)
# print("False Negatives: ",fn)
# print("True Positives: ",tp)

# Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
# print("Accuracy {:0.2f}%:".format(Accuracplt.scatter(features[:,0], features[:,1])y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95         9
#            1       1.00      0.88      0.93         8
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        79
#
#     accuracy                           0.99       131
#    macro avg       0.97      0.97      0.97       131
# weighted avg       0.99      0.99      0.99       131

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cf_matrix,annot=True)
plt.xlabel('Predicted')
# tmr_data_df.to_csv('/home/hp/Desktop/TMR-EDA/Data/encoded_tmr_data.csv',index=False)
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %% [markdown]
# <h2>Support Vector Classifier</h2>

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='rbf')
svclassifier.fit(X_train, y_train)
tmr_data_df['TechCategory'].value_counts()
y_pred = svclassifier.predict(X_test)

cf_matrix = confusion_matrix(y_test,y_pred)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.89      1.00      0.94         8
#            2       1.00      1.00      1.00        35
#            3       1.00      0.99      0.99        79
#
#     accuracy                           0.99       131
#    macro avg       0.97      1.00      0.98       131
# weighted avg       0.99      0.99      0.99       131

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cf_matrix,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
