# %%
import pandas as pd

# %%
missing_data_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Data/admit_id_with_missing_data.csv')
# This data is the data shared on 23rd Aug
live_data_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Data/New data live - Sheet1.csv')

# %%
missing_data_df.shape
# Out:
# (643, 18)

# %%
live_data_df.shape
# Out:
# (6308, 11)

# %%
missing_data_df.head(1)
# Out:
#          Admit ID Trial % Present Trail Last Internal Rating  \
# 0  CIC112020-7766          78.26%         Meets expectations
#
#    Trail Avg TRACK Score  Trail Techability Score (Out of 2.0)  \
# 0                   4.31                                  1.55
#
#    Trail Learnability Score (Out of 2.0)  \
# 0                                   1.76
#
#    Trail Communicability Score (Out of 1.0) RFP % Present RFP Last Status  \
# 0                                       1.0          100%  Need Less Help
#
#   RFP Last Internal Rating  RFP Last TRACK Score  \
# 0       Meets expectations                  4.64
#
#    RFP Tech Ability \n(Out of 2)  RFP- Learnability \n(Out of 2)  \
# 0                            1.6                            1.75
#
#    RFP-Communicability \n(Out of 1)  RFP Avg TRACK Score Last Graduation  \
# 0                              0.92                 4.27             NaN
#
#    Year TechCategory
# 0   NaN    FullStack

# %%
live_data_df.head(1)
# Out:
#          Admit Id Regularity Status                      Batch Name  \
# 0  CIC102020-7264           Regular  CIC-201-Akshay-Nov02-TRACK-2.3
#
#   Start Date % Present Last Internal Rating  Avg TRACK Score  \
# 0   2-Nov-20   100.00%                  NaN              NaN
#
#    Techability Score (Out of 2.0)  Learnability Score (Out of 2.0)  \
# 0                             NaN                              NaN
#
#    Communicability Score (Out of 1.0)  Avg TRACK Score.1
# 0                                 NaN                NaN

# %%
live_data_df = live_data_df.rename(columns={ 'Admit Id': 'Admit ID',
                                            '% Present': 'A', 
                                            'Last Internal Rating': 'B',
                                            'Avg TRACK Score': 'C',
                                            'Techability Score (Out of 2.0)': 'D',
                                            'Learnability Score (Out of 2.0)': 'E',
                                            'Communicability Score (Out of 1.0)': 'F',
                                           })

# %%
missing_data_df = missing_data_df.rename(columns={'Admit ID': 'Admit ID',
                                                  'Trial % Present': 'A', 
                                                  'Trail Last Internal Rating': 'B',
                                                  'Trail Avg TRACK Score': 'C',
                                                  'Trail Techability Score (Out of 2.0)': 'D',
                                                  'Trail Learnability Score (Out of 2.0)': 'E',
                                                  'Trail Communicability Score (Out of 1.0)': 'F',
                                                 })

# %%
live_data_df = live_data_df.sort_values(by=list(live_data_df.columns),na_position='last').drop_duplicates(subset=['Admit ID'],keep='first')

# %%
live_data_df = live_data_df.drop(['Avg TRACK Score.1', 'Batch Name','Regularity Status','Start Date'], axis=1)
live_data_df.shape
# Out:
# (5282, 7)

# %%
## combine first

# %%
live_data_df = live_data_df.set_index('Admit ID')
missing_data_df = missing_data_df.set_index('Admit ID')

res_out = missing_data_df.combine_first(live_data_df)
res_out.shape
# Out:
# (5284, 17)

# %%
res_out.head(3)
# Out:
#             A    B   C   D   E   F Last Graduation RFP % Present  \
# Admit ID
# NaN       NaN  NaN NaN NaN NaN NaN             NaN           NaN
# -         NaN  NaN NaN NaN NaN NaN             NaN           NaN
# Admit ID  NaN  NaN NaN NaN NaN NaN             NaN           NaN
#
#           RFP Avg TRACK Score RFP Last Internal Rating RFP Last Status  \
# Admit ID
# NaN                       NaN                      NaN             NaN
# -                         NaN                      NaN             NaN
# Admit ID                  NaN                      NaN             NaN
#
#           RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# Admit ID
# NaN                        NaN                            NaN
# -                          NaN                            NaN
# Admit ID                   NaN                            NaN
#
#           RFP- Learnability \n(Out of 2)  RFP-Communicability \n(Out of 1)  \
# Admit ID
# ...

# %%
import numpy as np
res_out = res_out.drop('Admit ID')
res_out = res_out.drop('-')
res_out = res_out.drop(np.NaN)

# %%
res_out.head(3)
# Out:
#                       A                     B      C      D      E      F  \
# Admit ID
# CIC012021-8041  100.00%  Exceeds expectations  3.690  1.625  1.475  0.590
# CIC012021-8042  100.00%    Meets expectations  3.705  1.660  1.450  0.595
# CIC012021-8044  100.00%    Meets expectations  3.230  1.560  1.050  0.620
#
#                      Last Graduation RFP % Present  RFP Avg TRACK Score  \
# Admit ID
# CIC012021-8041  B.E. / B.TECH Non IT           76%                 4.26
# CIC012021-8042                   NaN           NaN                  NaN
# CIC012021-8044                   NaN           NaN                  NaN
#
#                RFP Last Internal Rating RFP Last Status  RFP Last TRACK Score  \
# Admit ID
# CIC012021-8041                      NaN             NaN                   0.0
# CIC012021-8042                      NaN             NaN                   NaN
# CIC012021-8044                      NaN             NaN                   NaN
#
# ...

# %%
res_out.shape
# Out:
# (5281, 17)

# %%
res_out.loc[["CIC012022-10972"]]
# Out:
#                        A                   B       C       D      E     F  \
# Admit ID
# CIC012022-10972  100.00%  Meets expectations  4.1225  1.7075  1.475  0.94
#
#                   Last Graduation RFP % Present  RFP Avg TRACK Score  \
# Admit ID
# CIC012022-10972  B.E. / B.TECH CS           82%                 4.32
#
#                 RFP Last Internal Rating RFP Last Status  \
# Admit ID
# CIC012022-10972       Meets expectations  Need Less Help
#
#                  RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# Admit ID
# CIC012022-10972                  4.28                           1.56
#
#                  RFP- Learnability \n(Out of 2)  \
# Admit ID
# CIC012022-10972                            1.77
#
#                  RFP-Communicability \n(Out of 1) TechCategory    Year
# Admit ID
# CIC012022-10972                              0.99    FullStack  2020.0

# %%
live_data_df.loc[['CIC012022-10972']]
# Out:
#                        A                   B       C       D      E     F
# Admit ID
# CIC012022-10972  100.00%  Meets expectations  4.1225  1.7075  1.475  0.94

# %%
missing_data_df.loc[['CIC012022-10972']]
# Out:
#                        A    B   C   D   E   F RFP % Present RFP Last Status  \
# Admit ID
# CIC012022-10972  100.00%  NaN NaN NaN NaN NaN           82%  Need Less Help
#
#                 RFP Last Internal Rating  RFP Last TRACK Score  \
# Admit ID
# CIC012022-10972       Meets expectations                  4.28
#
#                  RFP Tech Ability \n(Out of 2)  \
# Admit ID
# CIC012022-10972                           1.56
#
#                  RFP- Learnability \n(Out of 2)  \
# Admit ID
# CIC012022-10972                            1.77
#
#                  RFP-Communicability \n(Out of 1)  RFP Avg TRACK Score  \
# Admit ID
# CIC012022-10972                              0.99                 4.32
#
#                   Last Graduation    Year TechCategory
# Admit ID
# CIC012022-10972  B.E. / B.TECH CS  2020.0    FullStack

# %%
## Final df

# %%
final_df = res_out.loc[res_out.index & missing_data_df.index]
final_df.shape
# Out:
# /tmp/ipykernel_8461/3858152744.py:1: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   final_df = res_out.loc[res_out.index & missing_data_df.index]
# (643, 17)

# %%
final_df.head(1)
# Out:
#                       A                     B     C      D      E     F  \
# Admit ID
# CIC012021-8041  100.00%  Exceeds expectations  3.69  1.625  1.475  0.59
#
#                      Last Graduation RFP % Present  RFP Avg TRACK Score  \
# Admit ID
# CIC012021-8041  B.E. / B.TECH Non IT           76%                 4.26
#
#                RFP Last Internal Rating RFP Last Status  RFP Last TRACK Score  \
# Admit ID
# CIC012021-8041                      NaN             NaN                   0.0
#
#                 RFP Tech Ability \n(Out of 2)  RFP- Learnability \n(Out of 2)  \
# Admit ID
# CIC012021-8041                           1.68                            1.72
#
#                 RFP-Communicability \n(Out of 1) TechCategory    Year
# Admit ID
# CIC012021-8041                              0.86    FullStack  2019.0

# %%
final_df.loc[['CIC102021-9885']]
# Out:
#                     A    B   C   D   E   F       Last Graduation  \
# Admit ID
# CIC102021-9885  7.14%  NaN NaN NaN NaN NaN  B.E. / B.TECH Non IT
#
#                RFP % Present  RFP Avg TRACK Score RFP Last Internal Rating  \
# Admit ID
# CIC102021-9885           97%                  4.3       Meets expectations
#
#                RFP Last Status  RFP Last TRACK Score  \
# Admit ID
# CIC102021-9885  Need Less Help                  4.02
#
#                 RFP Tech Ability \n(Out of 2)  RFP- Learnability \n(Out of 2)  \
# Admit ID
# CIC102021-9885                           1.61                            1.69
#
#                 RFP-Communicability \n(Out of 1) TechCategory    Year
# Admit ID
# CIC102021-9885                               1.0    FullStack  2021.0

# %%
final_df.to_csv('/home/hp/Desktop/TMR-EDA/Data/updated_trail_data.csv',index=True)

# %%
updated_trail_data_df =  pd.read_csv('/home/hp/Desktop/TMR-EDA/Data/updated_trail_data.csv')

# %%
updated_trail_data_df.shape
# Out:
# (643, 18)

# %% [markdown]
# <h2>Updating the trail values for the intersected admit id</h2>

# %%
tmr_data_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Data/TMR - intersected_admit_id.csv')

# %%
tmr_data_df.head(2)
# Out:
#          Admit ID Trial Regularity Status                  Trial Batch Name  \
# 0  CIC112020-7766                 Regular  CIC-224-Ashutosh-Nov19-TRACK-2.3
# 1  CIC122020-8002                 Regular   CIC-258-Shubham-Dec11-TRACK-2.3
#
#   Trail Last Batch Start Date Trial % Present Trail Last Internal Rating  \
# 0                   19-Nov-20          78.26%         Meets expectations
# 1                   15-Dec-20          93.75%                        NaN
#
#    Trail Avg TRACK Score  Trail Techability Score (Out of 2.0)  \
# 0                  4.310                                  1.55
# 1                  3.525                                  1.24
#
#    Trail Learnability Score (Out of 2.0)  \
# 0                                   1.76
# 1                                   1.44
#
#    Trail Communicability Score (Out of 1.0)  ... Aggregate Yrs of Exp  \
# 0                                     1.000  ...       NaN        NaN
# ...

# %%
tmr_data_df.shape
# Out:
# (1144, 38)

# %%
tmr_data_df = tmr_data_df[['Admit ID','Trial % Present','Trail Last Internal Rating','Trail Avg TRACK Score','Trail Techability Score (Out of 2.0)',
       'Trail Learnability Score (Out of 2.0)','Trail Communicability Score (Out of 1.0)','RFP % Present','RFP Last Status', 'RFP Last Internal Rating', 'RFP Last TRACK Score',
       'RFP Tech Ability \n(Out of 2)', 'RFP- Learnability \n(Out of 2)','RFP-Communicability \n(Out of 1)', 'RFP Avg TRACK Score','Last Graduation', 'Year','TechCategory']]

# %%
tmr_data_df.shape
# Out:
# (1144, 18)

# %%
tmr_data_df.columns.to_list()
# Out:
# ['Admit ID',
#  'Trial % Present',
#  'Trail Last Internal Rating',
#  'Trail Avg TRACK Score',
#  'Trail Techability Score (Out of 2.0)',
#  'Trail Learnability Score (Out of 2.0)',
#  'Trail Communicability Score (Out of 1.0)',
#  'RFP % Present',
#  'RFP Last Status',
#  'RFP Last Internal Rating',
#  'RFP Last TRACK Score',
#  'RFP Tech Ability \n(Out of 2)',
#  'RFP- Learnability \n(Out of 2)',
#  'RFP-Communicability \n(Out of 1)',
#  'RFP Avg TRACK Score',
#  'Last Graduation',
#  'Year',
#  'TechCategory']

# %%
tmr_data_df = tmr_data_df.rename(columns={'Admit ID': 'Admit ID',
                                          'Trial % Present': 'A', 
                                          'Trail Last Internal Rating': 'B',
                                          'Trail Avg TRACK Score': 'C',
                                          'Trail Techability Score (Out of 2.0)': 'D',
                                          'Trail Learnability Score (Out of 2.0)': 'E',
                                          'Trail Communicability Score (Out of 1.0)': 'F',
                                         })

# %%
tmr_data_df.columns.to_list()
# Out:
# ['Admit ID',
#  'A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'F',
#  'RFP % Present',
#  'RFP Last Status',
#  'RFP Last Internal Rating',
#  'RFP Last TRACK Score',
#  'RFP Tech Ability \n(Out of 2)',
#  'RFP- Learnability \n(Out of 2)',
#  'RFP-Communicability \n(Out of 1)',
#  'RFP Avg TRACK Score',
#  'Last Graduation',
#  'Year',
#  'TechCategory']

# %%
tmr_data_df = tmr_data_df.set_index('Admit ID')
updated_trail_data_df = updated_trail_data_df.set_index('Admit ID')

final_result = updated_trail_data_df.combine_first(tmr_data_df)
final_result.shape
# Out:
# (1144, 17)

# %%
final_result.isna().sum()
# Out:
# A                                     3
# B                                   182
# C                                    66
# D                                    69
# E                                    69
# F                                    69
# Last Graduation                      30
# RFP % Present                         3
# RFP Avg TRACK Score                  30
# RFP Last Internal Rating            270
# RFP Last Status                     275
# RFP Last TRACK Score                 47
# RFP Tech Ability \n(Out of 2)        30
# RFP- Learnability \n(Out of 2)       30
# RFP-Communicability \n(Out of 1)     30
# TechCategory                         30
# Year                                 51
# dtype: int64

# %%
final_result.tail(2)
# Out:
#                        A                   B      C     D      E     F  \
# Admit ID
# CIC122021-10690  100.00%  Meets expectations  4.205  1.57  1.695  0.94
# CIC122021-10700   64.29%  Improvement needed  4.310  1.64  1.820  0.85
#
#                              Last Graduation RFP % Present  \
# Admit ID
# CIC122021-10690         B.E. / B.TECH Non IT           29%
# CIC122021-10700  B.E. Information Technology           98%
#
#                  RFP Avg TRACK Score RFP Last Internal Rating RFP Last Status  \
# Admit ID
# CIC122021-10690                 3.61                      NaN             NaN
# CIC122021-10700                 4.15       Meets expectations  Need Less Help
#
#                  RFP Last TRACK Score  RFP Tech Ability \n(Out of 2)  \
# Admit ID
# CIC122021-10690                  3.44                           1.37
# CIC122021-10700                  4.15                           1.51
#
#                  RFP- Learnability \n(Out of 2)  \
# Admit ID
# ...

# %%
final_result = final_result.rename(columns={'A': 'Trial % Present', 
                                            'B': 'Trail Last Internal Rating',
                                            'C': 'Trail Avg TRACK Score',
                                            'D': 'Trail Techability Score (Out of 2.0)',
                                            'E': 'Trail Learnability Score (Out of 2.0)',
                                            'F': 'Trail Communicability Score (Out of 1.0)',                                         
                                           })

# %%
final_result.head(2)
# Out:
#                Trial % Present Trail Last Internal Rating  \
# Admit ID
# CIC012021-8041         100.00%       Exceeds expectations
# CIC012021-8044         100.00%         Meets expectations
#
#                 Trail Avg TRACK Score  Trail Techability Score (Out of 2.0)  \
# Admit ID
# CIC012021-8041                   3.69                                 1.625
# CIC012021-8044                   3.23                                 1.560
#
#                 Trail Learnability Score (Out of 2.0)  \
# Admit ID
# CIC012021-8041                                  1.475
# CIC012021-8044                                  1.050
#
#                 Trail Communicability Score (Out of 1.0)  \
# Admit ID
# CIC012021-8041                                      0.59
# CIC012021-8044                                      0.62
#
#                      Last Graduation RFP % Present  RFP Avg TRACK Score  \
# Admit ID
# CIC012021-8041  B.E. / B.TECH Non IT           76%                 4.26
# ...

# %%
final_result.to_csv('/home/hp/Desktop/TMR-EDA/Data/Final_Result.csv',index=True)
