# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/original_data.csv')

# %%
original_df.shape
# Out:
# (1144, 19)

# %%
data1_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/d1.csv')

# %%
data1_df.shape
# Out:
# (200, 19)

# %%
original_data1_df = original_df.append(data1_df)
# Out:
# /tmp/ipykernel_36688/3489412332.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   original_data1_df = original_df.append(data1_df)

# %%
original_data1_df.shape
# Out:
# (1344, 19)

# %%
original_data1_df.to_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/original_data1.csv', index=False)

# %%
data2_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/d2.csv')

# %%
data2_df.shape
# Out:
# (200, 19)

# %%
original_data1_data2_df = original_data1_df.append(data2_df)
# Out:
# /tmp/ipykernel_36688/2038073999.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   original_data1_data2_df = original_data1_df.append(data2_df)

# %%
original_data1_data2_df.shape
# Out:
# (1544, 19)

# %%
original_data1_data2_df.to_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/original_data1_data2.csv', index=False)

# %%
data3_df = pd.read_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/d3.csv')

# %%
data3_df.shape
# Out:
# (200, 19)

# %%
original_data1_data2_data3_df = original_data1_data2_df.append(data3_df)
# Out:
# /tmp/ipykernel_36688/1249895676.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   original_data1_data2_data3_df = original_data1_data2_df.append(data3_df)

# %%
original_data1_data2_data3_df.shape
# Out:
# (1744, 19)

# %%
original_data1_data2_data3_df.to_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/original_data1_data2_data3.csv', index=False)

# %%
original_data1_data2_data3_df.head(3)
# Out:
#          Admit ID RFP % Present RFP Last Status RFP Last Internal Rating  \
# 0  CIC012021-8041           76%    Need No Help       Meets expectations
# 1  CIC012021-8044           89%  Need Less Help       Improvement needed
# 2  CIC012021-8052           79%  Need Less Help       Meets expectations
#
#    RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# 0                   0.0              1.68               1.72
# 1                   3.6              1.22               1.51
# 2                   4.4              1.74               1.75
#
#         Last Graduation  RFP-Communicability  RFP Avg TRACK Score  \
# 0  B.E. / B.TECH Non IT                 0.86                 4.26
# 1      B.E. / B.TECH CS                 0.67                 3.40
# 2      B.E. / B.TECH CS                 0.93                 4.42
#
#   TechCategory  Trial Avg TRACK Score  Trial Communicability Score  \
# 0    FullStack                   3.69                         0.59
# 1    AdvTech-1                   3.23                         0.62
# 2    FullStack                   4.46                         0.94
#
#   Trial Last Internal Rating  Trial Learnability Score  \
# 0       Exceeds expectations                     1.475
# 1         Meets expectations                     1.050
# 2         Meets expectations                     1.790
#
#    Trial Techability Score Trial % Present    Year Practice Head
# 0                    1.625         100.00%  2019.0         Sunil
# 1                    1.560         100.00%  2020.0         Dilip
# 2                    1.730          84.62%  2020.0         Sunil

# %%
original_data1_data2_data3_df.drop(columns=['Trial Avg TRACK Score', 'Trial Communicability Score', 'Trial Last Internal Rating', 'Trial Learnability Score', 'Trial Techability Score', 'Trial % Present'], axis=1, inplace=True)

# %%
original_data1_data2_data3_df.shape
# Out:
# (1744, 13)

# %%
original_data1_data2_data3_df.isna().sum()
# Out:
# Admit ID                      0
# RFP % Present                18
# RFP Last Status             271
# RFP Last Internal Rating    271
# RFP Last TRACK Score         83
# RFP Tech Ability            157
# RFP- Learnability           158
# Last Graduation              48
# RFP-Communicability         159
# RFP Avg TRACK Score         157
# TechCategory                318
# Year                         93
# Practice Head                18
# dtype: int64

# %%
original_data1_data2_data3_df.dropna(inplace=True)

# %%
original_data1_data2_data3_df.isna().sum()
# Out:
# Admit ID                    0
# RFP % Present               0
# RFP Last Status             0
# RFP Last Internal Rating    0
# RFP Last TRACK Score        0
# RFP Tech Ability            0
# RFP- Learnability           0
# Last Graduation             0
# RFP-Communicability         0
# RFP Avg TRACK Score         0
# TechCategory                0
# Year                        0
# Practice Head               0
# dtype: int64

# %%
original_data1_data2_data3_df.shape
# Out:
# (1272, 13)

# %%
original_data1_data2_data3_df.reset_index(inplace = True, drop=True)

# %%
duplicate = original_data1_data2_data3_df[original_data1_data2_data3_df.duplicated()]
 
print("Duplicate Rows :")
 
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
#              Admit ID RFP % Present RFP Last Status RFP Last Internal Rating  \
# 1042  CIC032022-11547           71%  Need Less Help       Improvement needed
# 1043  CIC032022-11437           96%  Need Less Help       Improvement needed
# 1045  CIC032022-11449           98%  Need Less Help       Meets expectations
# 1051  CIC032022-11468          100%  Need Less Help       Improvement needed
# 1058  CIC032022-11425           83%    Need No Help       Meets expectations
# 1059  CIC032022-11590           99%    Need No Help       Meets expectations
# 1062  CIC032022-11454           98%    Need No Help       Meets expectations
# 1063  CIC032022-11494           71%  Need Less Help       Meets expectations
# 1064  CIC032022-11465           94%    Need No Help       Meets expectations
# 1066  CIC032022-11646          100%    Need No Help       Meets expectations
# 1070  CIC032022-11586          100%    Need No Help       Meets expectations
# 1071  CIC032022-11574          100%    Need No Help       Meets expectations
# 1073  CIC042022-11668           89%    Need No Help       Meets expectations
# 1074  CIC032022-11635          100%    Need No Help       Meets expectations
# 1076  CIC032022-11458           92%  Need More Help       Improvement needed
# 1082  CIC042022-11771           74%  Need Less Help       Meets expectations
# 1084  CIC032022-11629           92%  Need Less Help       Meets expectations
# 1085  CIC032022-11643           98%  Need Less Help       Meets expectations
# 1102  CIC042022-11887           88%    Need No Help       Meets expectations
# 1104  CIC042022-11677           85%  Need Less Help       Improvement needed
#
#       RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# 1042                  3.81              1.35               1.52
# 1043                  4.23              1.56               1.57
# 1045                  4.18              1.54               1.65
# 1051                  4.15              1.44               1.51
# 1058                  4.12              1.42               1.58
# 1059                  4.12              1.55               1.58
# 1062                  4.70              1.55               1.78
# 1063                  4.34              1.49               1.71
# 1064                  3.80              1.48               1.54
# 1066                  3.98              1.58               1.63
# 1070                  3.80              1.51               1.50
# 1071                  3.92              1.51               1.55
# 1073                  4.16              1.62               1.65
# 1074                  4.28              1.60               1.66
# 1076                  3.39              1.05               1.41
# 1082                  3.65              1.29               1.38
# 1084                  4.08              1.54               1.63
# 1085                  4.15              1.51               1.70
# 1102                  3.53              1.53               1.62
# 1104                  3.35              1.25               1.35
#
#            Last Graduation  RFP-Communicability  RFP Avg TRACK Score  \
# 1042  B.E. / B.TECH Non IT                 0.53                 3.39
# 1043         B.E. / B.TECH                 0.68                 3.81
# 1045  B.E. / B.TECH Non IT                 0.88                 4.06
# 1051  B.E. / B.TECH Non IT                 0.72                 3.67
# 1058  B.E. / B.TECH Non IT                 0.82                 3.83
# 1059      B.E. / B.TECH CS                 0.84                 3.97
# 1062      B.E. / B.TECH CS                 0.98                 4.31
# 1063      B.E. / B.TECH CS                 0.97                 4.17
# 1064         B.E. / B.TECH                 0.75                 3.77
# 1066  B.E. / B.TECH Non IT                 0.84                 4.05
# 1070  B.E. / B.TECH Non IT                 0.73                 3.74
# 1071  B.E. / B.TECH Non IT                 0.75                 3.81
# 1073             PG Non IT                 0.87                 4.14
# 1074      B.E. / B.TECH CS                 0.78                 4.04
# 1076                   MCA                 0.96                 3.41
# 1082  B.E. / B.TECH Non IT                 0.99                 3.66
# 1084         B.E. / B.TECH                 0.84                 4.01
# 1085  B.E. / B.TECH Non IT                 0.94                 4.15
# 1102         B.E. / B.TECH                 0.81                 3.96
# 1104  B.E. / B.TECH Non IT                 0.76                 3.36
#
#      TechCategory    Year Practice Head
# 1042    AdvTech-1  2019.0        Gunjan
# 1043    FullStack  2021.0        Gunjan
# 1045    FullStack  2019.0         Sunil
# 1051      StdTech  2018.0        Gunjan
# 1058    AdvTech-2  2016.0        Ashish
# 1059    AdvTech-1  2020.0        Ashish
# 1062    FullStack  2020.0      Nagendra
# 1063    AdvTech-1  2020.0      Nagendra
# 1064    FullStack  2018.0      Nagendra
# 1066    FullStack  2015.0      Nagendra
# 1070    AdvTech-1  2016.0      Nagendra
# 1071    FullStack  2021.0      Nagendra
# 1073     DeepTech  2018.0      Nagendra
# 1074    AdvTech-2  2019.0      Nagendra
# 1076    AdvTech-1  2020.0        Ashish
# 1082    FullStack  2020.0        Ashish
# 1084    FullStack  2021.0         Sunil
# 1085    FullStack  2018.0         Sunil
# 1102    FullStack  2019.0        Ashish
# 1104    FullStack  2020.0        Gunjan

# %%
original_data1_data2_data3_df[original_data1_data2_data3_df['Admit ID']=='CIC032022-11437']
# Out:
#              Admit ID RFP % Present RFP Last Status RFP Last Internal Rating  \
# 318   CIC032022-11437           96%  Need Less Help       Improvement needed
# 1043  CIC032022-11437           96%  Need Less Help       Improvement needed
#
#       RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# 318                   4.23              1.56               1.57
# 1043                  4.23              1.56               1.57
#
#      Last Graduation  RFP-Communicability  RFP Avg TRACK Score TechCategory  \
# 318    B.E. / B.TECH                 0.68                 3.81    FullStack
# 1043   B.E. / B.TECH                 0.68                 3.81    FullStack
#
#         Year Practice Head
# 318   2021.0        Gunjan
# 1043  2021.0        Gunjan

# %%
original_data1_data2_data3_df.drop_duplicates(keep='last', inplace=True)
original_data1_data2_data3_df.reset_index(inplace = True, drop=True)

# %%
original_data1_data2_data3_df[original_data1_data2_data3_df['Admit ID']=='CIC032022-11437']
# Out:
#              Admit ID RFP % Present RFP Last Status RFP Last Internal Rating  \
# 1023  CIC032022-11437           96%  Need Less Help       Improvement needed
#
#       RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# 1023                  4.23              1.56               1.57
#
#      Last Graduation  RFP-Communicability  RFP Avg TRACK Score TechCategory  \
# 1023   B.E. / B.TECH                 0.68                 3.81    FullStack
#
#         Year Practice Head
# 1023  2021.0        Gunjan

# %%
original_data1_data2_data3_df.shape
# Out:
# (1252, 13)

# %%
count = original_data1_data2_data3_df['Admit ID'].nunique()

print(count)
# Out:
# 1199

# %%
# original_data1_data2_data3_df = original_data1_data2_data3_df.drop_duplicates(subset='Admit ID')

# %%
original_data1_data2_data3_df.shape
# Out:
# (1252, 13)

# %%
original_data1_data2_data3_df.describe()
# Out:
#        RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# count           1252.000000       1252.000000        1252.000000
# mean               3.343175          1.393117           1.516540
# std                1.272648          0.183153           0.151337
# min                0.000000          0.610000           0.700000
# 25%                3.377500          1.290000           1.429643
# 50%                3.740000          1.400000           1.520000
# 75%                4.020000          1.516577           1.620000
# max                4.880000          1.860000           1.910000
#
#        RFP-Communicability  RFP Avg TRACK Score         Year
# count          1252.000000          1252.000000  1252.000000
# mean              0.800388             3.708782  2016.294728
# std               0.090625             0.362999    77.995728
# min               0.350000             1.750000    65.000000
# 25%               0.740000             3.510000  2018.000000
# 50%               0.800000             3.710000  2020.000000
# 75%               0.860000             3.940000  2020.250000
# max               1.070000             4.710000  2104.000000

# %%
df = original_data1_data2_data3_df.loc[(original_data1_data2_data3_df['Year']>2022) | (original_data1_data2_data3_df['RFP-Communicability']>1.0)]
df
# Out:
#              Admit ID RFP % Present RFP Last Status RFP Last Internal Rating  \
# 90    CIC012022-10935          100%    Need No Help     Exceeds expectations
# 502   CIC052022-12151          100%  Need More Help       Improvement needed
# 781    CIC092021-9697           98%  Need Less Help       Meets expectations
# 1151  CIC052022-12105       100.00%  Need More Help       Improvement needed
# 1155  CIC052022-12151       100.00%  Need More Help       Improvement needed
#
#       RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# 90                    4.64              1.73               1.79
# 502                   3.48              1.17               1.52
# 781                   4.03              1.48               1.71
# 1151                  3.59              1.39               1.59
# 1155                  3.48              1.17               1.52
#
#            Last Graduation  RFP-Communicability  RFP Avg TRACK Score  \
# 90     M.E. / M.Tech CS/IT                 0.97                 4.49
# 502              PG Non IT                 0.82                 3.52
# 781   M.E. / M.Tech Non IT                 0.80                 4.00
# 1151  B.E. / B.TECH Non IT                 1.07                 4.05
# 1155             PG Non IT                 0.82                 3.52
#
#      TechCategory    Year Practice Head
# 90      FullStack  2023.0        Gunjan
# 502     AdvTech-2  2023.0        Ashish
# 781     FullStack  2104.0        Gunjan
# 1151    FullStack  2016.0         Sunil
# 1155    AdvTech-1  2023.0        Ashish

# %%
original_data1_data2_data3_df = original_data1_data2_data3_df.drop(original_data1_data2_data3_df[(original_data1_data2_data3_df['Admit ID'] == 'CIC012022-10935') |          
                                           (original_data1_data2_data3_df['Admit ID'] == 'CIC052022-12151') | 
                                           (original_data1_data2_data3_df['Admit ID'] == 'CIC052022-12105') | 
                                           (original_data1_data2_data3_df['Admit ID'] == 'CIC092021-9697')].index)

# %%
original_data1_data2_data3_df.describe()
# Out:
#        RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# count           1247.000000       1247.000000        1247.000000
# mean               3.341167          1.393138           1.516101
# std                1.274488          0.183037           0.151329
# min                0.000000          0.610000           0.700000
# 25%                3.370000          1.290000           1.427411
# 50%                3.740000          1.400000           1.520000
# 75%                4.020000          1.517440           1.620000
# max                4.880000          1.860000           1.910000
#
#        RFP-Communicability  RFP Avg TRACK Score         Year
# count          1247.000000          1247.000000  1247.000000
# mean              0.800004             3.707951  2016.208500
# std               0.090353             0.362750    78.111815
# min               0.350000             1.750000    65.000000
# 25%               0.740000             3.510000  2018.000000
# 50%               0.800000             3.710000  2020.000000
# 75%               0.860000             3.940000  2020.000000
# max               1.000000             4.710000  2022.000000

# %%
original_data1_data2_data3_df.shape
# Out:
# (1247, 13)

# %%
# Removing the % symbol from the 'Trial % Present' and 'RFP % Present' columns

original_data1_data2_data3_df.replace('\%', '', regex=True,inplace=True)

# Changing the type of 'Trial % Present' and 'RFP % Present' columns from object to float
# original_data1_data2_data3_df['Trial % Present'] = original_data1_data2_data3_df['Trial % Present'].astype('float64')
original_data1_data2_data3_df['RFP % Present'] = original_data1_data2_data3_df['RFP % Present'].astype('float64')
original_data1_data2_data3_df.head(2)
# Out:
#          Admit ID  RFP % Present RFP Last Status RFP Last Internal Rating  \
# 0  CIC012021-8041           76.0    Need No Help       Meets expectations
# 1  CIC012021-8044           89.0  Need Less Help       Improvement needed
#
#    RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# 0                   0.0              1.68               1.72
# 1                   3.6              1.22               1.51
#
#         Last Graduation  RFP-Communicability  RFP Avg TRACK Score  \
# 0  B.E. / B.TECH Non IT                 0.86                 4.26
# 1      B.E. / B.TECH CS                 0.67                 3.40
#
#   TechCategory    Year Practice Head
# 0    FullStack  2019.0         Sunil
# 1    AdvTech-1  2020.0         Dilip

# %%
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["Practice Head"] == "Sunil Patil", "Practice Head"] = "Sunil"
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["Practice Head"] == "Sunil patil", "Practice Head"] = "Sunil"
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["Practice Head"] == "Ashish Vishwakarma", "Practice Head"] = "Ashish"

# %%
original_data1_data2_data3_df[original_data1_data2_data3_df['RFP Last TRACK Score']==0]
# Out:
#              Admit ID  RFP % Present RFP Last Status RFP Last Internal Rating  \
# 0      CIC012021-8041           76.0    Need No Help       Meets expectations
# 5      CIC012021-8078           74.0    Need No Help       Meets expectations
# 6      CIC012021-8083           63.0  Need Less Help       Meets expectations
# 46    CIC012022-10743           71.0  Need Less Help       Improvement needed
# 54    CIC012022-10782           93.0    Need No Help       Meets expectations
# ...               ...            ...             ...                      ...
# 997   CIC122021-10622           34.0  Need Less Help       Meets expectations
# 999   CIC122021-10628           77.0  Need Less Help       Improvement needed
# 1004  CIC122021-10639           37.0    Need No Help       Meets expectations
# 1005  CIC122021-10640           27.0  Need Less Help       Improvement needed
# 1009  CIC122021-10668           93.0  Need Less Help       Meets expectations
#
#       RFP Last TRACK Score  RFP Tech Ability  RFP- Learnability  \
# 0                      0.0              1.68               1.72
# 5                      0.0              1.59               1.82
# 6                      0.0              1.49               1.54
# 46                     0.0              1.34               1.49
# 54                     0.0              1.60               1.68
# ...                    ...               ...                ...
# 997                    0.0              1.54               1.76
# 999                    0.0              1.39               1.57
# 1004                   0.0              1.48               1.82
# 1005                   0.0              1.20               1.60
# 1009                   0.0              1.41               1.61
#
#            Last Graduation  RFP-Communicability  RFP Avg TRACK Score  \
# 0     B.E. / B.TECH Non IT                 0.86                 4.26
# 5     B.E. / B.TECH Non IT                 0.92                 4.33
# 6     B.E. / B.TECH Non IT                 0.79                 3.81
# 46    B.E. / B.TECH Non IT                 0.81                 3.64
# 54    B.E. / B.TECH Non IT                 0.85                 4.12
# ...                    ...                  ...                  ...
# 997       B.E. / B.TECH CS                 0.90                 4.20
# 999                 BSc CS                 0.81                 3.76
# 1004      B.E. / B.TECH CS                 0.88                 4.18
# 1005  B.E. / B.TECH Non IT                 0.84                 3.64
# 1009      B.E. / B.TECH CS                 0.81                 3.84
#
#      TechCategory    Year Practice Head
# 0       FullStack  2019.0         Sunil
# 5        DeepTech  2018.0         Dilip
# 6         StdTech  2020.0         Dilip
# 46      AdvTech-2  2020.0        Gunjan
# 54       DeepTech  2017.0      Nagendra
# ...           ...     ...           ...
# 997     FullStack  2021.0        Gunjan
# 999     FullStack  2021.0         Sunil
# 1004    AdvTech-1  2022.0        Ashish
# 1005    FullStack  2020.0        Gunjan
# 1009      StdTech  2018.0         Sunil
#
# [144 rows x 13 columns]

# %%
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["RFP Last TRACK Score"] == 0, "RFP Last TRACK Score"] = round(original_data1_data2_data3_df['RFP Last TRACK Score'].mean(),2)

# %%
original_data1_data2_data3_df[original_data1_data2_data3_df['RFP Last TRACK Score']==0]
# Out:
# Empty DataFrame
# Columns: [Admit ID, RFP % Present, RFP Last Status, RFP Last Internal Rating, RFP Last TRACK Score, RFP Tech Ability, RFP- Learnability, Last Graduation, RFP-Communicability, RFP Avg TRACK Score, TechCategory, Year, Practice Head]
# Index: []

# %%
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["TechCategory"] == "FullStack", "TechCategory"] = "FullStack_DeepTech"
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["TechCategory"] == "DeepTech", "TechCategory"] = "FullStack_DeepTech"
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["TechCategory"] == "AdvTech-1", "TechCategory"] = "AdvTech_1_2"
original_data1_data2_data3_df.loc[original_data1_data2_data3_df["TechCategory"] == "AdvTech-2", "TechCategory"] = "AdvTech_1_2"

# %% [markdown]
# ### Renaming Columns

# %%
original_data1_data2_data3_df = original_data1_data2_data3_df.rename(columns={ 
                           'RFP- Learnability':'RFP Learnability',
                           'RFP-Communicability':'RFP Communicability'
                            })

# %%
original_data1_data2_data3_df.to_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/final_data_before_encoding.csv', index=False)

# %% [markdown]
# ## Encoding ##

# %%
def bucketing_graduation(row):
    if row['Last Graduation'] in ['B.E. / B.TECH CS', 'B.E. / B.TECH IT', 'B.Tech Information Technology', 'Computer Science', 'B.E. Computer Engineering', 'B.Tech Computer Science','B.E. Information Technology']:
        return 'BE_BTECH_CS_IT'
    if row['Last Graduation'] in ['B.E. / B.TECH Non IT','B.E. Mechanical Engineering','Mechatronics Engineering','B.Tech Chemical engineering','B.Tech Electrical Engineering','B.Tech Electronics Engineering','B.E. Electrical Engineering','B.E. Electronics & Communication Engineering','B.E. CIVIL ENGINEERING','B.E. Electronics & Telecommunications']:
        return 'BE_BTECH_NON_IT'
    if row['Last Graduation'] in ['B.E. / B.TECH', 'B-tech']:
        return 'BE_BTECH'
    if row['Last Graduation'] in ['MCA', 'MSc CS/IT', 'MCA IT']:
        return 'MCA_MSc_CS_IT'
    if row['Last Graduation'] in ['MSc Non IT']:
        return 'MSc_Non_IT'
    if row['Last Graduation'] in ['M.E. / M.Tech CS/IT','PG CS/IT']:
        return 'ME_MTECH_PG_CS_IT'
    if row['Last Graduation'] in ['M.E. / M.Tech Non IT','PG Non IT']:
        return 'ME_MTECH_PG_Non_IT'
    if row['Last Graduation'] in ['BSc CS','BSc IT','BCA IT','BCA','BCA CS','Computer Application','Other IT']:
        return 'BCA_BSc_CS_Other_IT'
    if row['Last Graduation'] in ['BSc Non IT','BSc','Other Non IT','Diploma Non IT']:
        return 'BCA_BSc_Other_Diploma_Non_IT'


original_data1_data2_data3_df['Last Graduation'] = original_data1_data2_data3_df.apply(lambda row: bucketing_graduation(row), axis=1)

# %%
original_data1_data2_data3_df['Last Graduation'].value_counts()
# Out:
# BE_BTECH_NON_IT                 546
# BE_BTECH_CS_IT                  399
# MCA_MSc_CS_IT                   116
# BE_BTECH                         59
# BCA_BSc_CS_Other_IT              52
# ME_MTECH_PG_CS_IT                28
# BCA_BSc_Other_Diploma_Non_IT     20
# ME_MTECH_PG_Non_IT               19
# MSc_Non_IT                        6
# Name: Last Graduation, dtype: int64

# %%
# Encoding the feature 'Trial Last Internal Rating'
# original_data1_data2_df['Trial Last Internal Rating'] = original_data1_data2_df['Trial Last Internal Rating'].replace(
#                                     {'Unsatisfactory': 0, 'Improvement needed': 1, 'Meets expectations':2,
#                                      'Exceeds expectations':3,'Exceptional':4})

# # Encoding the feature 'RFP Last Internal Rating'
# original_data1_data2_df['RFP Last Internal Rating'] = original_data1_data2_df['RFP Last Internal Rating'].replace(
#                                     {'Unsatisfactory': 0, 'Improvement needed': 1, 'Meets expectations':2,
#                                      'Exceeds expectations':3,'Exceptional':4})

# # Encoding the feature 'TechCategory'
# original_data1_data2_df['TechCategory'] = original_data1_data2_df['TechCategory'].replace({'FullStack': 3, 'AdvTech-1': 2,'AdvTech-2':2,
#                                                  'BasicTech':1, 'StdTech':0, 'DeepTech':3})

# # Encoding the feature 'Practice Head'
# original_data1_data2_df['Practice Head'] = original_data1_data2_df['Practice Head'].replace({'Nagendra':0, 'Dilip':1,'Gunjan':2, 'Sunil':3,
#                                                     'Ashish':4})

# %%
# Encoding the feature 'RFP Last Status'
# original_data1_data2_df['RFP Last Status'] = original_data1_data2_df['RFP Last Status'].replace({'Need More Help':0, 'Need Less Help':1,'Need No Help':2})

# %%
original_data1_data2_data3_df['TechCategory'].value_counts()
# Out:
# FullStack_DeepTech    659
# AdvTech_1_2           390
# BasicTech             120
# StdTech                78
# Name: TechCategory, dtype: int64

# %%
# original_data1_data2_data3_df['Trial Last Internal Rating'].value_counts()

# %%
original_data1_data2_data3_df['RFP Last Status'].value_counts()
# Out:
# Need Less Help    793
# Need More Help    325
# Need No Help      129
# Name: RFP Last Status, dtype: int64

# %%
# labelEncoder present in scikitlearn library
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()

# original_data1_data2_data3_df['Trial Last Internal Rating'] = le.fit_transform(original_data1_data2_data3_df['Trial Last Internal Rating'])
# original_data1_data2_data3_df['RFP Last Internal Rating'] = le.fit_transform(original_data1_data2_data3_df['RFP Last Internal Rating'])
# original_data1_data2_data3_df['TechCategory'] = le.fit_transform(original_data1_data2_data3_df['TechCategory'])
# original_data1_data2_data3_df['Practice Head'] = le.fit_transform(original_data1_data2_data3_df['Practice Head'])
# original_data1_data2_data3_df['Last Graduation'] = le.fit_transform(original_data1_data2_data3_df['Last Graduation'])
# original_data1_data2_data3_df['RFP Last Status'] = le.fit_transform(original_data1_data2_data3_df['RFP Last Status'])

# %%
encoder_dict = dict()

for col in list(original_data1_data2_data3_df.columns):
    if original_data1_data2_data3_df[col].dtype == 'object' and col != 'Admit ID':
#         print(col)
        enc = le.fit(original_data1_data2_data3_df[col])
        original_data1_data2_data3_df[col] = le.transform(original_data1_data2_data3_df[col])
        encoder_dict[col] = enc

# %%
print(encoder_dict)
# Out:
# {'RFP Last Status': LabelEncoder(), 'RFP Last Internal Rating': LabelEncoder(), 'Last Graduation': LabelEncoder(), 'TechCategory': LabelEncoder(), 'Practice Head': LabelEncoder()}

# %%
import pickle

# %%
# saving the encoder objects
with open('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/encoder_dict.pickle', 'wb') as handle:
    pickle.dump(encoder_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/encoder_dict.pickle', 'rb') as handle:
    new_dict = pickle.load(handle)

# %%
print(new_dict)
# Out:
# {'RFP Last Status': LabelEncoder(), 'RFP Last Internal Rating': LabelEncoder(), 'Last Graduation': LabelEncoder(), 'TechCategory': LabelEncoder(), 'Practice Head': LabelEncoder()}

# %%
original_data1_data2_data3_df['TechCategory'].value_counts()
# Out:
# 2    659
# 0    390
# 1    120
# 3     78
# Name: TechCategory, dtype: int64

# %%
# original_data1_data2_data3_df['Trial Last Internal Rating'].value_counts()

# %%
original_data1_data2_data3_df['RFP Last Status'].value_counts()
# Out:
# 0    793
# 1    325
# 2    129
# Name: RFP Last Status, dtype: int64

# %%
# Encoding the feature 'Last Graduation'
# original_data1_data2_df['Last Graduation'] = original_data1_data2_df['Last Graduation'].replace({'MSc_Non_IT':0, 'BCA_BSc_Other_Diploma_Non_IT':1,'ME_MTECH_PG_Non_IT':2,
#                                                                                                 'ME_MTECH_PG_CS_IT':3, 'BE_BTECH':4,'BCA_BSc_CS_Other_IT':5,
#                                                                                              'MCA_MSc_CS_IT':6, 'BE_BTECH_CS_IT':7,'BE_BTECH_NON_IT':8})

# %%
original_data1_data2_data3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1247 entries, 0 to 1251
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Admit ID                  1247 non-null   object
#  1   RFP % Present             1247 non-null   float64
#  2   RFP Last Status           1247 non-null   int64
#  3   RFP Last Internal Rating  1247 non-null   int64
#  4   RFP Last TRACK Score      1247 non-null   float64
#  5   RFP Tech Ability          1247 non-null   float64
#  6   RFP Learnability          1247 non-null   float64
#  7   Last Graduation           1247 non-null   int64
#  8   RFP Communicability       1247 non-null   float64
#  9   RFP Avg TRACK Score       1247 non-null   float64
#  10  TechCategory              1247 non-null   int64
#  11  Year                      1247 non-null   float64
#  12  Practice Head             1247 non-null   int64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 136.4+ KB

# %%
original_data1_data2_data3_df['Last Graduation'].isna().sum()
# Out:
# 0

# %%
original_data1_data2_data3_df.dropna(inplace=True)

# %%
original_data1_data2_data3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1247 entries, 0 to 1251
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Admit ID                  1247 non-null   object
#  1   RFP % Present             1247 non-null   float64
#  2   RFP Last Status           1247 non-null   int64
#  3   RFP Last Internal Rating  1247 non-null   int64
#  4   RFP Last TRACK Score      1247 non-null   float64
#  5   RFP Tech Ability          1247 non-null   float64
#  6   RFP Learnability          1247 non-null   float64
#  7   Last Graduation           1247 non-null   int64
#  8   RFP Communicability       1247 non-null   float64
#  9   RFP Avg TRACK Score       1247 non-null   float64
#  10  TechCategory              1247 non-null   int64
#  11  Year                      1247 non-null   float64
#  12  Practice Head             1247 non-null   int64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 136.4+ KB

# %%
original_data1_data2_data3_df.head(3)
# Out:
#          Admit ID  RFP % Present  RFP Last Status  RFP Last Internal Rating  \
# 0  CIC012021-8041           76.0                2                         3
# 1  CIC012021-8044           89.0                0                         2
# 2  CIC012021-8052           79.0                0                         3
#
#    RFP Last TRACK Score  RFP Tech Ability  RFP Learnability  Last Graduation  \
# 0                  3.34              1.68              1.72                4
# 1                  3.60              1.22              1.51                3
# 2                  4.40              1.74              1.75                3
#
#    RFP Communicability  RFP Avg TRACK Score  TechCategory    Year  \
# 0                 0.86                 4.26             2  2019.0
# 1                 0.67                 3.40             0  2020.0
# 2                 0.93                 4.42             2  2020.0
#
#    Practice Head
# 0              4
# 1              1
# 2              4

# %%
# Dropping the 'Admit ID' column

original_data1_data2_data3_df.drop('Admit ID', axis=1, inplace=True)

# %%
original_data1_data2_data3_df.head(2)
# Out:
#    RFP % Present  RFP Last Status  RFP Last Internal Rating  \
# 0           76.0                2                         3
# 1           89.0                0                         2
#
#    RFP Last TRACK Score  RFP Tech Ability  RFP Learnability  Last Graduation  \
# 0                  3.34              1.68              1.72                4
# 1                  3.60              1.22              1.51                3
#
#    RFP Communicability  RFP Avg TRACK Score  TechCategory    Year  \
# 0                 0.86                 4.26             2  2019.0
# 1                 0.67                 3.40             0  2020.0
#
#    Practice Head
# 0              4
# 1              1

# %%
original_data1_data2_data3_df.to_csv('/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/final_encoded_data_with_d1_d2_d3.csv', index=False)

# %%
original_data1_data2_data3_df.shape
# Out:
# (1247, 12)

# %% [markdown]
# # Model Building

# %%
# columns = ['RFP Avg TRACK Score','RFP Tech Ability','RFP Learnability','RFP Communicability','Trial Communicability Score',
#            'Trial Last Internal Rating','Trial Learnability Score','Trial Techability Score','Practice Head','TechCategory']

# %%
columns = ['RFP % Present', 'RFP Last Status', 'Practice Head', 'RFP Avg TRACK Score', 'RFP Last TRACK Score', 'RFP Tech Ability', 'Year', 'RFP Learnability', 'RFP Communicability', 'RFP Last Internal Rating', 'Last Graduation','TechCategory']
columns
# Out:
# ['RFP % Present',
#  'RFP Last Status',
#  'Practice Head',
#  'RFP Avg TRACK Score',
#  'RFP Last TRACK Score',
#  'RFP Tech Ability',
#  'Year',
#  'RFP Learnability',
#  'RFP Communicability',
#  'RFP Last Internal Rating',
#  'Last Graduation',
#  'TechCategory']

# %%
df = original_data1_data2_data3_df[columns]
df.head()
# Out:
#    RFP % Present  RFP Last Status  Practice Head  RFP Avg TRACK Score  \
# 0           76.0                2              4                 4.26
# 1           89.0                0              1                 3.40
# 2           79.0                0              4                 4.42
# 3           97.0                1              1                 3.24
# 4           76.0                0              4                 4.13
#
#    RFP Last TRACK Score  RFP Tech Ability    Year  RFP Learnability  \
# 0                  3.34              1.68  2019.0              1.72
# 1                  3.60              1.22  2020.0              1.51
# 2                  4.40              1.74  2020.0              1.75
# 3                  3.32              1.21  2020.0              1.29
# 4                  4.28              1.59  2020.0              1.66
#
#    RFP Communicability  RFP Last Internal Rating  Last Graduation  \
# 0                 0.86                         3                4
# 1                 0.67                         2                3
# 2                 0.93                         3                3
# 3                 0.74                         2                3
# 4                 0.88                         3                3
#
#    TechCategory
# 0             2
# 1             0
# 2             2
# 3             1
# 4             0

# %%
# splitting dataframe by row index
# part_90_df = df.iloc[:860,:]
# part_10_df = df.iloc[860:,:]
# print(part_90_df.shape)
# print(part_10_df.shape)

# %%
y = df['TechCategory']
X = df.drop(['TechCategory'], axis=1)

# %%
# from sklearn.preprocessing import StandardScaler
# columns = X.columns
# sc = StandardScaler()
# sc.fit(X)
# X = pd.DataFrame(sc.transform(X), columns=columns)

# %%
# X.head(2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
import joblib

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Generate a sample dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_classes=2, random_state=42)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the base classifiers to be used in the stacking model
estimators = [('lr', LogisticRegression()), ('dt', DecisionTreeClassifier()), ('gnb', GaussianNB()), ('svc', SVC())]

# Define the stacking model with a Logistic Regression meta-classifier
stack = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# Train the stacking model on the training set
stack.fit(X_train, y_train)

# Predict the labels of the test set using the trained stacking model
y_pred = stack.predict(X_test)


y_predd = stack.predict(X_train)
acc = accuracy_score(y_train, y_predd)
print("Train Accuracy:", acc)

# Calculate the accuracy of the predictions
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Train Accuracy: 0.6571100917431193
# Accuracy: 0.608
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
def model_buidling(X, y , classifier, n_cross_validation, param_grid):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=100)
    clf_Grid = GridSearchCV(estimator = classifier, param_grid=param_grid, cv=n_cross_validation, verbose=2, n_jobs=4)
    clf_Grid.fit(X_train, y_train)
    train_accuracy = clf_Grid.score(X_train, y_train)
    test_accuracy = clf_Grid.score(X_test, y_test)
    return clf_Grid, clf_Grid.best_params_, train_accuracy, test_accuracy

# %% [markdown]
# ## SVC

# %%
svc_clf = SVC(gamma='auto')
param_Grid = {'C':[0.1,1,10,100],
              'gamma':[1,0.1,0.01,0.001],
              'kernel':['rbf']
            }

# %%
clf_svc, best_params, train_accuracy, test_accuracy = model_buidling(X, y, svc_clf, 10, param_Grid)
print(best_params)
print(train_accuracy)
print(test_accuracy)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.6018054162487463
# 0.52

# %%
# Save the model as a pickle in a file
joblib.dump(clf_svc, '/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/model_svc.pkl')
# Out:
# ['/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/model_svc.pkl']

# %% [markdown]
# ## Random Forest

# %%
# The number of trees in the forest.
n_estimators = [ int(x) for x in np.linspace(start=10, stop=80, num=10) ]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [2,3,4,5,10]
# Minimum number of samples required to split a node
min_samples_split = [2,3,5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1,2]
# Method of selecting samples for training each tree
bootstrap = [True, False]


# Create the param grid
param_grid = {'n_estimators': n_estimators,
              'max_features': max_features,
              'max_depth': max_depth,
              'min_samples_split': min_samples_split,
              'min_samples_leaf': min_samples_leaf,
              'bootstrap': bootstrap}

# %%
rf_clf = RandomForestClassifier(random_state=42)

# %%
clf_rf, best_params, train_accuracy, test_accuracy = model_buidling(X, y, rf_clf, 10, param_grid)
# Out:
# Fitting 10 folds for each of 1200 candidates, totalling 12000 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.0s
# [CV] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.0s
# ...
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s

# %%
print(best_params)
print(train_accuracy)
print(test_accuracy)
# Out:
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 72}
# 0.6770310932798396
# 0.56

# %%
# Save the model as a pickle in a file
joblib.dump(clf_rf, '/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/model_rf.pkl')
# Out:
# ['/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/model_rf.pkl']

# %% [markdown]
# ## Logistic Regression

# %%
lr_clf = LogisticRegression()

param_grid = [{
                'penalty':['l1','l2'],
                'C':np.logspace(-4,4,20),
                'solver':['lbfgs','newton-cg','liblinear'],
                'max_iter':[100,1000,2500]
            }]

# %%
clf_lr, best_params, train_accuracy, test_accuracy = model_buidling(X, y, lr_clf, 10, param_grid)
# Out:
# Fitting 10 folds for each of 360 candidates, totalling 3600 fits
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.1s
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=0.0001, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.6s
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80; total time=   0.2s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ...C=0.0001, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.3s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0001, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.5s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.4s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.00026366508987303583, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=0.0006951927961775605, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 1200 fits failed out of a total of 3600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/hp/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/hp/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/home/hp/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/hp/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.53962626 0.53762626 0.53962626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53962626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53962626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53762626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53762626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53762626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53762626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53762626 0.53762626
#         nan        nan 0.53962626 0.53762626 0.53762626 0.53762626
#         nan        nan 0.53962626 0.53662626 0.53962626 0.53762626
#         nan        nan 0.53962626 0.53962626 0.53962626 0.53762626
#         nan        nan 0.53962626 0.53962626 0.53962626 0.53762626
#         nan        nan 0.53962626 0.54262626 0.54363636 0.54163636
#         nan        nan 0.53962626 0.54264646 0.54363636 0.54163636
#         nan        nan 0.53962626 0.54264646 0.54363636 0.54163636
#         nan        nan 0.53762626 0.55167677 0.55768687 0.54464646
#         nan        nan 0.53762626 0.55366667 0.55768687 0.54464646
#         nan        nan 0.53762626 0.55366667 0.55768687 0.54464646
#         nan        nan 0.55667677 0.55367677 0.56974747 0.56568687
#         nan        nan 0.55667677 0.56871717 0.56874747 0.56568687
#         nan        nan 0.55667677 0.56874747 0.56874747 0.56568687
#         nan        nan 0.56972727 0.54057576 0.57171717 0.57172727
#         nan        nan 0.57073737 0.57070707 0.57371717 0.57172727
#         nan        nan 0.56972727 0.57171717 0.57371717 0.57172727
#         nan        nan 0.58575758 0.54056566 0.57567677 0.57571717
#         nan        nan 0.58575758 0.56470707 0.57867677 0.57571717
#         nan        nan 0.58676768 0.57271717 0.57867677 0.57571717
#         nan        nan 0.58775758 0.53859596 0.58067677 0.58273737
#         nan        nan 0.58875758 0.56367677 0.58067677 0.58273737
#         nan        nan 0.58575758 0.57370707 0.58067677 0.58273737
#         nan        nan 0.58876768 0.53153535 0.57970707 0.58574747
#         nan        nan 0.58976768 0.56771717 0.57870707 0.58574747
#         nan        nan 0.59077778 0.58170707 0.57870707 0.58574747
#         nan        nan 0.58977778 0.54362626 0.58071717 0.58775758
#         nan        nan 0.59078788 0.57466667 0.58270707 0.58775758
#         nan        nan 0.58978788 0.58470707 0.58270707 0.58775758
#         nan        nan 0.59078788 0.53263636 0.58471717 0.58776768
#         nan        nan 0.59179798 0.56466667 0.58371717 0.58776768
#         nan        nan 0.58978788 0.57871717 0.58371717 0.58776768
#         nan        nan 0.59078788 0.54358586 0.58371717 0.58877778
#         nan        nan 0.59178788 0.56860606 0.58472727 0.58877778
#         nan        nan 0.59178788 0.58169697 0.58472727 0.58877778
#         nan        nan 0.59178788 0.55067677 0.58071717 0.58977778
#         nan        nan 0.58977778 0.57873737 0.58171717 0.58977778
#         nan        nan 0.59078788 0.57971717 0.58171717 0.58977778
#         nan        nan 0.59078788 0.55968687 0.58271717 0.58977778
#         nan        nan 0.59379798 0.56464646 0.58272727 0.58977778
#         nan        nan 0.59278788 0.57771717 0.58272727 0.58977778
#         nan        nan 0.59278788 0.53860606 0.58171717 0.58877778
#         nan        nan 0.58978788 0.57168687 0.58172727 0.58877778
#         nan        nan 0.59178788 0.58271717 0.58172727 0.58877778
#         nan        nan 0.59178788 0.55165657 0.58271717 0.59077778
#         nan        nan 0.59179798 0.56561616 0.58071717 0.59077778
#         nan        nan 0.59279798 0.57671717 0.58071717 0.59077778
#         nan        nan 0.59279798 0.54663636 0.58271717 0.58877778
#         nan        nan 0.59078788 0.56070707 0.58071717 0.58877778
#         nan        nan 0.59179798 0.58375758 0.58071717 0.58877778
#         nan        nan 0.59078788 0.54063636 0.58171717 0.58877778
#         nan        nan 0.59178788 0.57169697 0.58171717 0.58877778
#         nan        nan 0.59178788 0.57869697 0.58171717 0.58877778]
#   warnings.warn(

# %%
print(best_params)
print(train_accuracy)
print(test_accuracy)
# Out:
# {'C': 206.913808111479, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.5997993981945837
# 0.572

# %%
# Save the model as a pickle in a file
joblib.dump(clf_lr, '/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/model_lr.pkl')
# Out:
# ['/home/hp/Desktop/TMR-EDA/Code/10_01_2023/data_for_10_01_2023/model_lr.pkl']
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.7s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.2s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.3s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.7s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.2s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.6s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.7s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.7s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.8s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.3s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END ..C=10000.0, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.8s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.9s
# [CV] END C=10000.0, max_iter=100, penalty=l2, solver=newton-cg; total time=   1.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.4s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   1.8s
# [CV] END .C=10000.0, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END .C=10000.0, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END .C=10000.0, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END .C=10000.0, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   3.2s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   4.8s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.8s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.8s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.8s
# [CV] END .C=10000.0, max_iter=2500, penalty=l2, solver=lbfgs; total time=   1.7s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   2.8s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   2.8s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   3.0s
# [CV] END .C=10000.0, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .C=10000.0, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .C=10000.0, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .C=10000.0, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.8s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.3s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.6s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.4s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.4s
# [CV] END C=10000.0, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END .C=10000.0, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END .C=10000.0, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   4.2s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   4.3s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   4.4s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   4.3s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   3.8s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.1s
# [CV] END C=3792.690190732246, max_iter=100, penalty=l2, solver=newton-cg; total time=   1.1s
# [CV] END C=3792.690190732246, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=3792.690190732246, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l1, solver=liblinear; total time=   2.9s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.1s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.4s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.3s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l2, solver=newton-cg; total time=   2.8s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l2, solver=newton-cg; total time=   4.4s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l2, solver=newton-cg; total time=   2.9s
# [CV] END C=3792.690190732246, max_iter=1000, penalty=l2, solver=newton-cg; total time=   5.4s
# [CV] END C=3792.690190732246, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.4s
# [CV] END C=3792.690190732246, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.7s
# [CV] END C=3792.690190732246, max_iter=2500, penalty=l2, solver=newton-cg; total time=   3.7s
# [CV] END C=3792.690190732246, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.4s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   2.8s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   3.6s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   2.7s
# [CV] END C=10000.0, max_iter=1000, penalty=l2, solver=newton-cg; total time=   4.3s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.1s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   4.2s
# [CV] END C=10000.0, max_iter=2500, penalty=l2, solver=newton-cg; total time=   3.7s
